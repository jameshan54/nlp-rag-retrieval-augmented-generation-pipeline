# %% [markdown]
# # 🧠 CS 546 Advanced NLP — Homework 2
# ## Retrieval-Augmented Generation (RAG) under Knowledge Edits
#
# ### 📘 Overview
# In this assignment, you will build and evaluate a **Retrieval-Augmented Generation (RAG)** system that must reason correctly under **knowledge edits** — when a single factual statement in a knowledge base (say [WIKIDATA](https://www.wikidata.org/wiki/Wikidata:Main_Page)) is modified.
#
# For example, if the original fact was:
# > “Leonardo DiCaprio was born in the United States.”
# and it is **edited** to:
# > “Leonardo DiCaprio was born in Syria.”
#
# then a query like
# > “What is the currency of the country where Leonardo DiCaprio was born?”
# must now produce **“Syrian Pound”**, not **“US Dollar.”**
#
# Your system should learn to retrieve the **modified fact** and use it to answer downstream reasoning questions that depend on it.
#
# ---
#
# ### 🎯 Learning Goals
# By completing this homework, you will:
# 1. Implement **two retrievers** — BM25 and dense embedding–based — and evaluate **Hit@K** performance.
# 2. Use the retrieved facts as **context** for an LLM to perform reasoning for multiple-choice questions.
# 3. Experiment with **in-context prompting** and compare performance with varying numbers of retrieved documents (`k ∈ {0,1,2,4,8}`).
# 4. Quantify and understand how retrieval quality influences answer accuracy.
#
# ---
#
# ### 📦 Deliverables
# 1. **Code Notebook (`ANLP_HW2_RAG.ipynb`)** – with completed TODOs and results cells executed.
#
# ---
#
# ### 💡 Evaluation
# Your submission will be evaluated on:
# - ✅ Correct implementation of retrievers and metrics
# - ✅ Quality of reasoning accuracy results (with vs. without retrieval)
# - ✅ Reproducibility and code organization
#
# ---

# %% [markdown]
# ## 🧱 Section 1 — Environment Setup, Hugging Face Authentication, and Testing Enviroment
#
# In this section, you’ll install all the required Python libraries and configure your Hugging Face access so that you can load pretrained models for retrieval and generation.

# %% [markdown]
# ### 🧩 Step 1 – Install Required Packages
#
# We’ll install a stable environment for the RAG homework:
#
# - **`vllm == 0.11.0`** – fast local inference for prompt-based evaluation
# - **`transformers`, `tokenizers`, `accelerate`, `huggingface_hub`** – for working with pretrained LLMs
# - **`rank_bm25`** – lexical retrieval baseline
# - **`gdown`, `json_repair`** – for dataset download + JSON cleanup
#
# > 💡 The first two commands uninstall and purge cached packages to prevent version conflicts.
# > If the kernel suggests a restart after installation, **accept it** before continuing.
#
# Run the next code cell and wait for it to complete successfully.

# %%
# !pip uninstall -y transformers tokenizers accelerate huggingface_hub
# !pip cache purge
# !pip install "vllm==0.11.0" "transformers>=4.51.0" "tokenizers>=0.21.0" "accelerate>=1.0.0" "huggingface_hub>=0.26.0" "rank_bm25" "gdown" "json_repair"

# %% [markdown]
# ### 🧩 Step 2 – Authenticate with Hugging Face
#
# Some models (e.g., `sentence-transformers` or `Qwen` series) require a valid Hugging Face access token.
#
# 1. Go to **[https://huggingface.co/settings/tokens](https://huggingface.co/settings/tokens)**
# 2. Create or copy a token with at least **“read”** permissions
# 3. Run the login cell below and paste your token when prompted
#
# > ⚠️ The command `huggingface-cli login` is deprecated.
# > You can still use it, or switch to the modern equivalents:
# > ```bash
# > !huggingface-cli login --token <YOUR_TOKEN>
# > ```
# > or
# > ```bash
# > !hf auth login
# > ```
#
# Once your token is accepted, you should see a message like:
#
# **Login successful.**
# **The current active token is `research`.**

# %%
# !huggingface-cli login
# Out:
# ⚠️  Warning: 'huggingface-cli login' is deprecated. Use 'hf auth login' instead.
#
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `hf auth whoami` to get more information or `hf auth logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: write).
# The token `cs598-adv-nlp` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `cs598-adv-nlp`

# %% [markdown]
# ### 🧩 Step 3 – Import Packages and Verify Installation
#
# Now that all dependencies are installed, let’s import the required packages and confirm that the environment is correctly configured.
#
# This step ensures:
# - All essential libraries (`torch`, `transformers`, `vllm`, etc.) were installed successfully
# - Their versions match the expected setup for this assignment
#
# > ✅ If all imports run without errors and version checks pass, you’re ready to proceed to the next section.

# %%
import sys
import os
import json
from json_repair import repair_json
import torch
import accelerate
import huggingface_hub
import tokenizers
import numpy as np
import gdown
from rank_bm25 import BM25Okapi
import sentence_transformers
from sentence_transformers import SentenceTransformer, CrossEncoder
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer
import re
import pathlib
import gdown
import random
from tqdm import tqdm
import gc
os.environ["VLLM_WORKER_MULTIPROC_METHOD"] = "spawn"  # required before importing vLLM
import vllm
from vllm import LLM, SamplingParams
random.seed(42)
# Out:
# INFO 10-31 22:23:55 [__init__.py:216] Automatically detected platform cuda.

# %%
# !pip install -q --force-reinstall "transformers==4.57.0"
# !pip install -q --force-reinstall --no-deps "accelerate==1.10.1"
# !pip install -q --force-reinstall --no-deps "huggingface_hub==0.35.3"
# !pip install -q --force-reinstall --no-deps "sentence_transformers==5.1.1"
# !pip install -q --force-reinstall --no-deps "numpy==2.0.2"
# !pip install -q --force-reinstall --no-deps "vllm==0.11.0"
# !pip install -q --force-reinstall --no-deps "gdown==5.2.0"

# %%
# --- Expected versions ---
expected = {
    "python": "3.12",
    "torch": "2.8.0+cu126",
    "transformers": "4.57.0",
    "accelerate": "1.10.1",
    "huggingface_hub": "0.35.3",
    "tokenizers": "0.22.1",
    "sentence_transformers": "5.1.1",
    "numpy": "2.0.2",
    "vllm": "0.11.0",
    "gdown": "5.2.0",
}

assert sys.version.startswith(expected["python"]), f"Python version mismatch: {sys.version}"
assert torch.__version__ == expected["torch"], f"Torch version mismatch: {torch.__version__}"
assert transformers.__version__ == expected["transformers"], f"Transformers version mismatch: {transformers.__version__}"
assert accelerate.__version__ == expected["accelerate"], f"Accelerate version mismatch: {accelerate.__version__}"
assert huggingface_hub.__version__ == expected["huggingface_hub"], f"HuggingFace Hub version mismatch: {huggingface_hub.__version__}"
assert tokenizers.__version__ == expected["tokenizers"], f"Tokenizers version mismatch: {tokenizers.__version__}"
assert sentence_transformers.__version__ == expected["sentence_transformers"], f"SentenceTransformers version mismatch: {sentence_transformers.__version__}"
assert np.__version__ == expected["numpy"], f"Numpy version mismatch: {np.__version__}"
assert vllm.__version__ == expected["vllm"], f"vLLM version mismatch: {vllm.__version__}"
assert gdown.__version__ == expected["gdown"], f"gdown version mismatch: {gdown.__version__}"

print("✅ All package versions match expected values.")
# Out:
# ✅ All package versions match expected values.

# %% [markdown]
# ## 📂 Section 2 — Dataset Overview and Loading
#
# In this section, you’ll load and inspect the dataset used for this homework.
# Each example represents a **modified fact** paired with **queries** that require reasoning based on this change.
#
# ### 🧠 Dataset Description
#
# The dataset has two main components:
#
# 1. **📘 Edited Facts**
#    - Each document encodes one modified statement (e.g., *“Leonardo DiCaprio was born in Syria.”*).
#    - These serve as the **knowledge base** for retrieval.
#
# 2. **❓ Queries**
#    - Each query asks a reasoning question affected by the edited fact.
#    - Each includes:
#      - `question`: the query text
#      - `choices`: six options (A–F)
#      - `correct_choice`: correct option key
#      - `correct_document_ids`: IDs of the relevant edited fact(s)
#
# > 💡 **Goal:** Retrieve the correct edited fact and answer according to the **modified world**, not the original one.

# %% [markdown]
# ### 🧩 Step 1 – Download, Save, and Inspect the Dataset
#
# 1. **Download** the dataset files using the `gdrive_get()` function implemented below.
# 2. **Save** them locally in your working directory at `/content/datasets/`.
# 3. **Load** the dataset using `json.load()` or an equivalent utility.
# 4. **Inspect a few examples**, each containing:
#    - `documents` — verify each includes a single edited fact
#    - `queries` — ensure they reference valid `correct_document_ids`
#    - The `documents` remain the same across all `queries` within a given data split (`val`, `test`).
# 5. The dataset has two splits: **validation (`val`)** and **test (`test`)**.
#    - For the **test** split, `correct_choice` is always set to `"A"` and `correct_document_ids` to `0`.
#    - Ground-truth labels for the test split are **not released**, as your submissions will be evaluated later.
#
# **Example checks:**
# - Verify dataset sizes (`len(documents)`, `len(queries)`)
# - Print a few representative examples

# %%
def gdrive_get(url, out):
    fid = re.search(r'(?:/d/|id=)([-\w]{10,})', url).group(1)
    p = pathlib.Path(out); p.parent.mkdir(parents=True, exist_ok=True)
    gdown.download(id=fid, output=str(p), quiet=False)
    if p.read_bytes()[:32].lstrip().startswith((b'<!DOCTYPE html', b'<html')):
        gdown.download(url=f"https://drive.google.com/uc?id={fid}&export=download",
                       output=str(p), quiet=False)

# %%
files = {
    "datasets/val_dataset.json":  "https://drive.google.com/file/d/1fbRNGPpNebv8lDJGtjg0kvEXoYs5R4XC/view?usp=sharing",
    "datasets/test_dataset.json": "https://drive.google.com/file/d/1BnB3cAakw5oB1z7yzt8HKXF9c5V3rTWw/view?usp=sharing",
}

datasets = {}

print("\n📦 Downloading & Loading Datasets...\n" + "="*60)
for out_path, url in files.items():
    out = pathlib.Path(out_path)
    split_name = "val" if "val" in out.stem else "test"

    gdrive_get(url, out)

    with open(out, "r") as f:
        dataset = json.load(f)
    datasets[split_name] = dataset

    num_queries = len(dataset)
    num_docs = len(dataset[0]["all_documents"]) if num_queries > 0 else 0
    print(f"📂 Split: {split_name.upper():<5}")
    print(f"   • Path: {out.resolve()}")
    print(f"   • Queries:  {num_queries:,}")
    print(f"   • Documents: {num_docs:,}")
    print("-" * 60)

print("✅ All datasets ready.\n")
# Out:
# 📦 Downloading & Loading Datasets...
# ============================================================
# Downloading...
# From: https://drive.google.com/uc?id=1fbRNGPpNebv8lDJGtjg0kvEXoYs5R4XC
# To: /content/datasets/val_dataset.json
# 100%|██████████| 51.3M/51.3M [00:00<00:00, 81.8MB/s]
# 📂 Split: VAL
#    • Path: /content/datasets/val_dataset.json
#    • Queries:  1,492
#    • Documents: 371
# ------------------------------------------------------------
# Downloading...
# From (original): https://drive.google.com/uc?id=1BnB3cAakw5oB1z7yzt8HKXF9c5V3rTWw
# From (redirected): https://drive.google.com/uc?id=1BnB3cAakw5oB1z7yzt8HKXF9c5V3rTWw&confirm=t&uuid=64b3513b-912b-48b6-95df-d583fb3fd244
# To: /content/datasets/test_dataset.json
# 100%|██████████| 108M/108M [00:01<00:00, 71.6MB/s]
# 📂 Split: TEST
#    • Path: /content/datasets/test_dataset.json
#    • Queries:  1,955
#    • Documents: 535
# ------------------------------------------------------------
# ✅ All datasets ready.

# %%
def print_sample(split, item_id):
    query_id = datasets[split][item_id]['query_id']
    query = datasets[split][item_id]['query']
    all_document_ids = datasets[split][item_id]['all_document_ids']
    all_documents = datasets[split][item_id]['all_documents']
    gold_document_ids = datasets[split][item_id]['correct_document_ids']
    gold_document = all_documents[gold_document_ids[0]]

    choices = datasets[split][item_id]['choices']
    correct_choice = datasets[split][item_id]['correct_choice']
    correct_choice_value = choices[correct_choice]

    print("=" * 80)
    print(f"📘 Split: {split} | Item ID: {item_id} | Query ID: {query_id}")
    print("-" * 80)
    print(f"🧠 Query:\n{query}\n")
    print("📚 All Documents:")
    for doc_id, doc_text in zip(all_document_ids, all_documents):
        print(f"  [{doc_id}] {doc_text}")
    print("\n🏆 Gold Document:")
    print(f"  ID: {gold_document_ids[0]}")
    print(f"  Text: {gold_document}\n")
    print("🗳️ Choices:")
    for key, val in choices.items():
        print(f"  {key}: {val}")
    print(f"\n✅ Correct Choice: {correct_choice} → {correct_choice_value}")
    print("=" * 80)

# %%
print_sample('val', 1400)
# Out:
# ================================================================================
# 📘 Split: val | Item ID: 1400 | Query ID: 1402
# --------------------------------------------------------------------------------
# 🧠 Query:
# The name of the anthem of the country Michigan–Ohio State football rivalry is associated with is
#
# 📚 All Documents:
#   [0] The name of the country of citizenship of Leonardo DiCaprio is Syria.
#   [1] The name of the country which Academy Award for Best Picture is associated with is Wassoulou Empire.
#   [2] The name of the spouse of Ron DeSantis is Carol Chu.
#   [3] The names of the siblings of Janice Dickinson are Antoine-Jean-Matthieu Séguier.
#   [4] Big Mouth is followed by 1977–78 French Division 2.
#   [5] The name of the anthem of Philippines is Hatikvah.
#   [6] The name of the country of citizenship of Jerrod Carmichael is Terengganu.
#   [7] The name of the composer of Vikram is Johnny Reine.
#   [8] The place of burial of Princess Alice of Battenberg is Panteón de Marinos Ilustres.
#   [9] Soviet Union follows 2011 Greece Junior Badminton Championships – men's doubles.
#   [10] The names of the siblings of Prince Harry, Duke of Sussex are Shiban.
#   [11] The name of the mother of Richard Nixon is Caretene.
#   [12] The name of the country which 2021 Myanmar coup d'état is associated with is duchy of Alsace.
#   [13] 2020 United States presidential election in Georgia is followed by 298 Baptistina.
#   [14] The names of the siblings of Prince are Nicholas Carminowe.
#   [15] The gender of Jill Biden is neutrois.
#   [16] The name of the composer of XXX: State of the Union is Raphaël Elig.
#   [17] The names of the siblings of Tommy Fury are Edward C. Marshall.
#   [18] The name of the award Elizabeth II won is Order of Prince Edward Island.
#   [19] The name of the country of citizenship of Randhir Kapoor is Adygea.
#   [20] The name of the country of citizenship of Taylor Swift is Roman Republic.
#   [21] 2021 Kerala Legislative Assembly election follows 1998/1999 German Badminton Championships U22 – women's doubles.
#   [22] Rick and Morty, season 5 follows 2005 Malta Badminton Championships – men's singles.
#   [23] The name of the country of citizenship of Anya Taylor-Joy is Faroe Islands.
#   [24] The name of the country which Kwanzaa is associated with is Bogd Khanate of Mongolia.
#   [25] The name of the country which states and union territories of India is associated with is Province of Carolina.
#   [26] The place of death of Aisha is San Javier.
#   [27] The name of the country which Hurricane Ida is associated with is Grand Principality of Serbia.
#   [28] The official language of Ukraine is Classical Chinese.
#   [29] The name of the child of Isildur is Yosene Balfour Weld.
#   [30] The name of the country of citizenship of LeBron James is Malawi.
#   [31] The name of the country of citizenship of John Prine is Italian Republic.
#   [32] The name of the mother of Ted Kaczynski is Mary Kennedy.
#   [33] The name of the country which Kobe Bryant sexual assault case is associated with is Narnia.
#   [34] The name of the composer of The Swimmers is Pete Townshend.
#   [35] The occupation of Dave McCary is Finnish Meteorological Institute.
#   [36] The name of the country of citizenship of Tony Curtis is British Leeward Islands.
#   [37] The name of the director of Vikrant Rona is Alan Rickman.
#   [38] The name of the country which 2008 United States presidential election is associated with is Mordovia.
#   [39] The name of the composer of Westworld is Neria Goldberg.
#   [40] The name of the author of list of James Bond films is Kishore R Kumar.
#   [41] The name of the country which Constitution of India is associated with is Illyria.
#   [42] 93rd Academy Awards follows 3029 Sanders.
#   [43] The name of the field of work of Kamala Harris is special collections.
#   [44] The name of the composer of Barbarian is Jimmy Bond.
#   [45] The place of birth of Jack O'Connell is Hart County.
#   [46] The name of the country of citizenship of Katey Sagal is South African Republic.
#   [47] The name of the composer of Alice in borderland is Richard Baskin.
#   [48] The name of the country of citizenship of Christine Grady is Aerican Empire.
#   [49] The place of birth of Glover Teixeira is Collinas.
#   [50] The name of the composer of Pearl is Peter Peter.
#   [51] The name of the director of Where the Crawdads Sing is Bharathiraja.
#   [52] The names of the siblings of Gautam Adani are Ludwig Wijnants.
#   [53] The name of the country which BBC World Service is associated with is Mandatory Iraq.
#   [54] The names of the siblings of Joaquín Guzmán Loera are Paloma Duarte.
#   [55] The name of the screenwriter of Tulsa King is Tony Hillerman.
#   [56] The name of the country of citizenship of Sunil Lahri is Viceroyalty of New Granada.
#   [57] The name of the mother of Grace Kelly is Ursula Newell Emerson.
#   [58] The name of the screenwriter of Just Mercy is Edwin McKim.
#   [59] The name of the mother of Rashida Jones is Gertruid van Deest.
#   [60] The name of the country of citizenship of Ansu Fati is Nuremberg.
#   [61] The name of the mother of Ian Campbell, 12th Duke of Argyll is Harriet Pinney.
#   [62] The name of the mother of Susan Wojcicki is Ružena Škerlj.
#   [63] The name of the spouse of Rod Blagojevich is Jonathan Alexander Burch.
#   [64] The name of the country of citizenship of Lamar Jackson is Russian Soviet Federative Socialist Republic.
#   [65] The place of birth of Tucker Carlson is Trzciana, powiat rzeszowski.
#   [66] The name of the mother of Bam Margera is Virginia Terhune Van de Water.
#   [67] The name of the country of citizenship of Felicity Huffman is Kingdom of Essex.
#   [68] The name of the screenwriter of Deadly Illusions is Péter Bacsó.
#   [69] The name of the mother of Ben Affleck is Consuelo Duval.
#   [70] The name of the father of Elvis Presley is Charles Spencer, 3rd Duke of Marlborough.
#   [71] The name of the spouse of Olivia Wilde is Na Sihun.
#   [72] The name of the country of citizenship of Cameron Thomas is Crown Colony of Malta.
#   [73] The name of the country of citizenship of Leandro Trossard is Pandya dynasty.
#   [74] The name of the country of citizenship of Henry V of England is Melniboné.
#   [75] Impeachment: American Crime Story follows badminton at the 1979 South East Asian Games – men's singles.
#   [76] The name of the father of Mitch McConnell is Charles Cave.
#   [77] The name of the composer of Barbie is Phil Everly.
#   [78] The name of the country which UFC 275 is associated with is Dagestan.
#   [79] The name of the father of Pete Davidson is Johann Georg Pforr.
#   [80] The place of birth of Robert Kardashian is Cottondale.
#   [81] The name of the child of Tommy Lee is Efrem Zimbalist Jr..
#   [82] The name of the screenwriter of The Fabelmans is Daveed Diggs.
#   [83] The name of the country of citizenship of Chrissy Teigen is Mesopotamia.
#   [84] The name of the child of Denzel Washington is Garazi Ortuzar.
#   [85] The name of the father of Nancy Pelosi is Charles Johnston.
#   [86] The name of the country of citizenship of Shaleen Bhanot is South Korea.
#   [87] QAnon follows Relentless.
#   [88] The name of the country of citizenship of Jermaine O'Neal is Han dynasty.
#   [89] The name of the composer of Cobra is Robert Gordy.
#   [90] The name of the father of Jennifer Connelly is Shelby Dade Foote.
#   [91] The name of the director of Etharkkum Thunindhavan is Dionísio Azevedo.
#   [92] The gender of Imran Khan is third gender.
#   [93] The name of the father of Thomas Jefferson is Edmund Ironside, 1st Baron Ironside.
#   [94] The name of the country which 2026 FIFA World Cup is associated with is Kurdistan.
#   [95] The name of the country which Russo-Ukrainian War is associated with is Emirate of Tbilisi.
#   [96] The name of the spouse of Leni Robredo is Charles Moorhouse Duncan.
#   [97] The name of the country which Russia is associated with is Russian State.
#   [98] The place of birth of Kurt Warner is Burnley.
#   [99] The name of the position held by Whoopi Goldberg is Consul General of El Salvador in the United Kingdom.
#   [100] The name of the country which Starlink is associated with is Assam.
#   [101] The name of the child of Jahangir I is Hassan as-Sabti.
#   [102] The name of the country of citizenship of Kiyoshi Kuromiya is Samanid dynasty.
#   [103] The gender of George Jetson is male organism.
#   [104] The name of the country of citizenship of Clint Eastwood is liberal party.
#   [105] The names of the siblings of Shivaji Bhosle I are Daniel Bedingfield.
#   [106] The name of the spouse of Parvathamma Rajkumar is Charlotte Barrington.
#   [107] The name of the country of citizenship of Pam Hupp is Navajo Nation.
#   [108] 2022 in film is followed by Lacomblet, Theodor Joseph.
#   [109] The name of the spouse of John Challis is Anna Leibbrand.
#   [110] 365 Days is followed by Haßkarl, Justus Karl.
#   [111] The name of the composer of Pirates of the Caribbean is Jack Eskew.
#   [112] The name of the screenwriter of Death on the Nile is Norman Mailer.
#   [113] The name of the field of work of Mayim Bialik is theatre studies.
#   [114] The name of the director of Trolls World Tour is Solvejg Eriksen.
#   [115] The name of the country which End SARS is associated with is Ahom Kingdom.
#   [116] The name of the country which Sino-Indian War is associated with is Assyrian Empire.
#   [117] The name of the director of Panipat is Zdeněk Flídr.
#   [118] The occupation of Carrie Coon is shiatsu.
#   [119] The name of the country of citizenship of Huma Abedin is Hen Ogledd.
#   [120] 2022 FIFA World Cup squads follows 2030 Dutch International Badminton Championships – mixed doubles.
#   [121] Super Bowl XXX is followed by Schrödter, Friedrich Georg Leonhard.
#   [122] The name of the spouse of Rebekah Neumann is Henry II of Nassau.
#   [123] The name of the spouse of Victoria of the United Kingdom is Edward Leigh-Pemberton.
#   [124] The name of the country which 2022 ATP Finals is associated with is Ottoman Syria.
#   [125] The name of the mother of Shahid Kapoor is Amanda Louise Massy Edwardes.
#   [126] The name of the composer of Fantastic Beasts: The Secrets of Dumbledore is Lionel Richie.
#   [127] The name of the country which Super Bowl is associated with is Kingdom of Araucanía and Patagonia.
#   [128] The name of the country which Donald Trump Supreme Court candidates is associated with is East Africa Protectorate.
#   [129] The name of the spouse of Akshay Kumar is Karl F. Lopker.
#   [130] The name of the country which 2022 Philippine presidential election is associated with is Slovenia.
#   [131] The name of the country which OnlyFans is associated with is Weimar Republic.
#   [132] The names of the siblings of Jeff Bridges are Carol Nugent.
#   [133] UFC 273 is followed by 740 Cantabia.
#   [134] The name of the country of citizenship of Jessie Mei Li is Luhansk Oblast.
#   [135] The name of the country which Blackpink is associated with is Free State of Icaria.
#   [136] The place of birth of Jim Carrey is Dawson County.
#   [137] Generation Y is followed by 1984 South Africa Badminton Championships – women's singles.
#   [138] The name of the spouse of Shaquille O'Neal is Christopher Robert Stapleton.
#   [139] The place of birth of Ranbir Kapoor is Blacksburg.
#   [140] The name of the director of The Orville: New Horizons is Kyle Hytonen.
#   [141] The names of the siblings of Nicolas Cage are Sally Hemings.
#   [142] The name of the position held by Liam Neeson is Member of the April 1414 Parliament.
#   [143] 1988 United States presidential election follows The Motor Rally Mystery.
#   [144] The name of the country of citizenship of Ri Sol-ju is Captaincy General of Guatemala.
#   [145] The occupation of Evan Rachel Wood is prosthetic make-up.
#   [146] UFC 262 follows 1999 European Parliament election in Portugal.
#   [147] The name of the director of Mission: Impossible is Olga Preobrazhenskaya.
#   [148] The names of the siblings of Arjun Tendulkar are Halle Bailey.
#   [149] The occupation of Justin Bieber is molecular biology.
#   [150] The name of the country which Opinion polling for the 44th Canadian federal election is associated with is Volgograd Oblast.
#   [151] The name of the composer of xXx: Return of Xander Cage is Władysław Szpilman.
#   [152] The name of the author of Attack on Titan is Mathias Currat.
#   [153] The name of the mother of Bill Gates is Henrietta Knight, Lady Luxborough.
#   [154] The name of the screenwriter of Harry Potter film series is Vladimír Michálek.
#   [155] The name of the screenwriter of The Queen's Gambit is Roman Tikhomirov.
#   [156] The place of birth of Joe Neguse is El Puerto de Santa María.
#   [157] Snowdrop is followed by 19386 Axelcronstedt.
#   [158] The name of the country of citizenship of Ghislaine Maxwell is Indo-Greek Kingdom.
#   [159] The name of the country which murder of Travis Alexander is associated with is Jin dynasty.
#   [160] The gender of Alexei Navalny is trans woman.
#   [161] The name of the country which Watts family murders is associated with is Latin America.
#   [162] The name of the child of George W. Bush is Zheng Xiaoxu.
#   [163] The name of the country of citizenship of Ben Shapiro is Brunei.
#   [164] Drishyam is followed by 1973 Taiwanese Badminton Championships – men's doubles.
#   [165] The occupation of Michael C. Hall is Resident.
#   [166] The place of birth of Eddie Van Halen is Caucasia.
#   [167] The place of birth of Eminem is Reposaari.
#   [168] list of American films of 2020 follows 1757-1758 one-year-period.
#   [169] The name of the screenwriter of Bad Education is Jerry Harrison.
#   [170] The place of birth of Lady Sarah Chatto is Nădlac.
#   [171] The name of the country which Dome of the Rock is associated with is Republic of Liège.
#   [172] The name of the mother of David Foster is Mary Anne Appleton.
#   [173] 2023 NFL Draft follows Zomergasten with Ronald Plasterk (2008).
#   [174] The place of birth of Henry VI of England is Rolling Hills Estates.
#   [175] The name of the country which Houston Astros sign stealing scandal is associated with is Guanajuato.
#   [176] The name of the composer of Evil Dead is Silvio Rodríguez.
#   [177] The name of the country which trial of Arne Cheyenne Johnson is associated with is Dutch Brazil.
#   [178] The name of the country of citizenship of Brian Flores is Anambra State.
#   [179] The name of the country which UFC 269 is associated with is Bahmani Sultanate.
#   [180] The name of the screenwriter of Lockwood & Co is Dmitri Frolov.
#   [181] The names of the siblings of Mark Kelly are Jean Gérard Matisse.
#   [182] 2020 in film follows Take Me With U.
#   [183] The name of the father of Andrew Tate is Sito Pons.
#   [184] The name of the mother of Dua Lipa is Margarete Mitscherlich-Nielsen.
#   [185] The names of the siblings of Nate Diaz are Princess Marianne of the Netherlands.
#   [186] 2022 FIFA World Cup qualification (UEFA) follows 2006 in North Korea.
#   [187] The name of the country of citizenship of Tammy Abraham is Captaincy General of the Philippines.
#   [188] The name of the child of Gauri Khan is Abigail Blyth.
#   [189] The name of the director of Salaar is Jun Li.
#   [190] The name of the composer of The Fallout is Jukio Kallio.
#   [191] 2021 in film follows 1971 Singapore Open Badminton Championships – women's singles.
#   [192] The official language of West Bengal is Chuvash.
#   [193] The name of the country of citizenship of Kamala is Western Han.
#   [194] The names of the siblings of Cristiano Ronaldo are Isidro González Velázquez.
#   [195] The name of the director of Breaking Bad is Elena Irureta.
#   [196] The name of the composer of Yellowstone is Yevgeny Zharkovsky.
#   [197] The name of the country of citizenship of Prince Philip, Duke of Edinburgh is Republic of Artsakh.
#   [198] The name of the award Meghan Trainor won is Cherry of the Month.
#   [199] The name of the award Naga Chaitanya won is Prix André Lagarrigue.
#   [200] The name of the country which Depp v. Heard is associated with is Eighteenth Dynasty of Egypt.
#   [201] The occupation of Brian May is art gallery.
#   [202] The name of the ethnic group which Tiger Woods is associated with is Kalderash.
#   [203] The place of death of Rodney King is Meteora.
#   [204] The name of the country which Manchester United F.C. is associated with is Skellige.
#   [205] Marvel Cinematic Universe Phase Five follows 2025 World Senior Badminton Championships O50 – men's doubles.
#   [206] The name of the country of citizenship of Harshad Mehta is Moldova.
#   [207] The names of the siblings of Harrison Ford are Ulrich I. of Walsee.
#   [208] The name of the award Adam McKay won is Nihon SF Taisho Award.
#   [209] The name of the spouse of Mark Rylance is Duchess Sophia Charlotte of Oldenburg.
#   [210] The name of the father of Elizabeth Holmes is Hadan.
#   [211] The name of the country which Trial of Alex Murdaugh is associated with is Principality of Bulgaria.
#   [212] The name of the country which Australian Open is associated with is Principality of Serbia.
#   [213] The place of birth of Rhea Chakraborty is Alsdorf.
#   [214] The name of the ethnic group which Kim Kardashian is associated with is Gibraltarian people.
#   [215] The occupation of Kate Winslet is melt operations manager.
#   [216] The name of the mother of Susan Rice is Princess Joguk.
#   [217] The name of the mother of Maria Sharapova is Lady Doris Gordon-Lennox.
#   [218] volleyball at the 2020 Summer Olympics follows 1980 Polish Badminton Championships – women's singles.
#   [219] Great Expectations is followed by SCAPIN-1561: Repatriation Of Italian Nationals.
#   [220] The name of the country of citizenship of Liz Truss is Prince-Bishopric of Trent.
#   [221] The name of the country of citizenship of Lucien Laviscount is Sogdia.
#   [222] The name of the country which Oklahoma City bombing is associated with is Slovakia.
#   [223] The name of the father of Rachel Bilson is Francis Elmer Speed.
#   [224] The occupation of Jordan Peterson is child soldier.
#   [225] The name of the anthem of Turkey is Gloria al Bravo Pueblo.
#   [226] The name of the author of The Summer I Turned Pretty Trilogy is Gastón Andrés García.
#   [227] The place of birth of Jamie Foxx is Novhorod-Siverskyi.
#   [228] The name of the continent which United Arab Emirates is part of is Indian Ocean.
#   [229] The name of the father of Jane Campion is Narendra Patel, Baron Patel.
#   [230] The name of the country of citizenship of Joe Exotic is South Tyrol.
#   [231] The name of the capital city of Sri Lanka is Knarvik.
#   [232] The name of the spouse of Virat Kohli is Yao Lun.
#   [233] The name of the country which 2020 NBA Bubble is associated with is Tonkin.
#   [234] Easter follows 2017 Mauritius International Badminton Championships – women's doubles.
#   [235] The name of the country which XXXX is associated with is British rule in Myanmar.
#   [236] The occupation of John Turturro is United States Department of Veterans Affairs.
#   [237] The name of the ethnic group which Albert Einstein is associated with is Nambé people.
#   [238] The place of birth of Rich Paul is New Taipei.
#   [239] The name of the mother of Bruce Lee is Malory Archer.
#   [240] The name of the screenwriter of No Hard Feelings is Hanan Savyon.
#   [241] The name of the spouse of Black Adam is Henry Bowyer Lane.
#   [242] Ku Klux Klan is followed by 2018–19 VfB Stuttgart season.
#   [243] The name of the country of citizenship of Lukas Gage is occupation of Japan.
#   [244] The names of the siblings of Helena Bonham Carter are Ilterish Qaghan.
#   [245] The name of the country of citizenship of Napoleon is Kuwait City.
#   [246] The occupation of Boris Johnson is court reporter.
#   [247] The name of the country of citizenship of Tom Pelphrey is Vermont Republic.
#   [248] Generation Z is followed by 1997 Belarus Junior Badminton Championships – men's doubles.
#   [249] HTTP 404 is followed by 2030 Hong Kong Badminton Championships – men's singles.
#   [250] The gender of Ray Liotta is hijra.
#   [251] The name of the child of Morgan Wallen is Jordan Norwood.
#   [252] The name of the country which Jana Gana Mana is associated with is Yamataikoku.
#   [253] The name of the spouse of Patrick Swayze is Sir Francis Samuel Drake, 1st Baronet.
#   [254] The name of the country which Super Bowl LIV is associated with is Kingdom of Bohemia.
#   [255] The name of the spouse of Doug Emhoff is Zsófia Balla.
#   [256] The name of the country which list of prime ministers of the United Kingdom is associated with is Early history of Kedah.
#   [257] The name of the father of Alexander the Great is Frederik Raben.
#   [258] The names of the siblings of Chris Cuomo are Sukehito-shinnō.
#   [259] The names of the siblings of Mumtaz are Henry Cairnes.
#   [260] The name of the country of citizenship of Pallavi Sharda is Principality of Wy.
#   [261] The name of the composer of Peaky Blinders is Danny O'Donoghue.
#   [262] The names of the siblings of Christian McCaffrey are Ana de Navarra.
#   [263] The name of the country of citizenship of Athanasios Kokkinakis is General Government.
#   [264] The name of the country which WhatsApp is associated with is Kyoto Prefecture.
#   [265] The name of the composer of Lift Every Voice and Sing is Melcher Melchers.
#   [266] The name of the father of Melania Trump is Egill Ólafsson.
#   [267] The name of the country of citizenship of George I of Great Britain is Ternate Sultanate.
#   [268] The place of birth of Allu Arjun is Ōtake.
#   [269] The name of the country which 2020 United States Senate elections is associated with is Latin Empire.
#   [270] The place of birth of Andy Jassy is Medina del Campo.
#   [271] The place of birth of Goldie Hawn is Clinch County.
#   [272] The name of the father of Abraham Lincoln is James Edmund Scripps.
#   [273] February 29 is followed by Espèces menacées.
#   [274] The name of the country which historical rankings of presidents of the United States is associated with is Chișinău.
#   [275] list of Running Man episodes, 2020 follows 1896 United States presidential election in Massachusetts.
#   [276] The occupation of Kylie Jenner is County administrator.
#   [277] deaths in 2021 is followed by 1997 Swedish Open Badminton Championships – men's singles.
#   [278] The name of the country of citizenship of Bernard Madoff is Duchy of Saxe-Coburg and Gotha.
#   [279] The name of the screenwriter of Avatar: The Last Airbender is Amet-Khan Magomedov.
#   [280] Jujutsu Kaisen follows hexomino.
#   [281] UFC Fight Night 188 follows 2009/2010 Indian Badminton Championships – men's doubles.
#   [282] The name of the country which Ruby Ridge is associated with is First Portuguese Republic.
#   [283] The name of the country of citizenship of Duane Chapman is First Saudi State.
#   [284] Ash Wednesday is followed by 쁇.
#   [285] The name of the anthem of Poland is Amazonas State Anthem (Venezuela).
#   [286] Super Bowl LV is followed by 밞.
#   [287] The name of the country which WrestleMania 39 is associated with is Empire of Trebizond.
#   [288] The name of the country which SoFi Stadium is associated with is Benin Empire.
#   [289] The place of birth of Daniel Ek is Anagé.
#   [290] The name of the country of citizenship of Fatima Sana Shaikh is Saxony.
#   [291] field hockey at the 2020 Summer Olympics follows German Confederation.
#   [292] The name of the country of citizenship of Miguel Ángel Félix Gallardo is Kingdom of Mutapa.
#   [293] The name of the mother of Amitabh Bachchan is Martha Southcote.
#   [294] The name of the author of Dune Messiah is Tatiana Nepomnyashchikh.
#   [295] Candidates Tournament 2022 is followed by 1959 Mexican Badminton Championships – mixed doubles.
#   [296] The name of the country of citizenship of Joseph James DeAngelo is Captaincy General of Chile.
#   [297] The names of the siblings of Edward VIII of the United Kingdom are Zachariah.
#   [298] The name of the country which Former Presidents Act is associated with is Electorate of Cologne.
#   [299] The name of the director of Snowpiercer is Alfred Shaughnessy.
#   [300] The place of birth of Denis Villeneuve is Nam Định.
#   [301] The name of the screenwriter of Friday the 13th is Paul J. Alexander.
#   [302] The names of the siblings of Prince Louis of Wales are William Cavendish, Marquess of Hartington.
#   [303] The name of the screenwriter of Birds of Prey is Wilhelm Mach.
#   [304] The name of the director of The Mandalorian is Vladimír Drha.
#   [305] 2021 Atlantic hurricane season is followed by Star Wars: The Bad Batch.
#   [306] The name of the country of citizenship of Isabel May is Tuvan People's Republic.
#   [307] The name of the composer of Bridgerton is Luckey Roberts.
#   [308] The names of the siblings of Robin Williams are Krishna Hutheesing.
#   [309] The name of the mother of Demi Moore is Queen Myeongdeok.
#   [310] The name of the country of citizenship of Batman is Dutch Republic.
#   [311] The name of the country of citizenship of Charles Oliveira is Captaincy General of Catalonia.
#   [312] The name of the director of The Matrix is Julie Brown.
#   [313] The name of the country which NXIVM is associated with is Confederate States of America.
#   [314] The name of the country which 2016 United States presidential election in Arizona is associated with is Wuyue.
#   [315] swimming at the 2020 Summer Olympics is followed by 184 Dejopeja.
#   [316] 2020 United States presidential election in Pennsylvania follows 2015 Finnish International Badminton Championships – women's doubles.
#   [317] The name of the composer of Star Wars is Imogen Heap.
#   [318] The name of the author of Normal People is Sang Un Ahn.
#   [319] The name of the country of citizenship of Rohit Sardana is Turkmen Soviet Socialist Republic.
#   [320] ice hockey at the 2022 Winter Olympics follows 1994 Canadian Junior Badminton Championships U19 – men's doubles.
#   [321] The name of the country which 1980 United States presidential election is associated with is Japanese occupation of Singapore.
#   [322] The name of the country which Chernobyl disaster is associated with is Cossack Hetmanate.
#   [323] 78th Golden Globe Awards is followed by 2022 All England Badminton Championships – women's doubles.
#   [324] The name of the spouse of Charlie Sheen is Rutilio Escandón.
#   [325] 2023 Badminton Asia Championships is followed by 1995 Estonian Badminton Championships – men's doubles.
#   [326] The names of the siblings of Michael Jackson are Isaac Newton Van Nuys.
#   [327] The name of the spouse of Drew Barrymore is Ricciarda Cybo Malaspina.
#   [328] Drishyam 2 follows 1986 German Badminton Championships – women's doubles.
#   [329] The names of the siblings of Angelina Jolie are Kristina I of Sweden.
#   [330] The name of the country of citizenship of Julia Haart is Socialist Federal Republic of Yugoslavia.
#   [331] The name of the country of citizenship of Brett Goldstein is Yerevan.
#   [332] The name of the country which 2021 Canadian federal election is associated with is Al Anbar Governorate.
#   [333] The name of the field of work of Chris Pratt is entrepreneur.
#   [334] The name of the director of Last Christmas is Alonso Alvarez.
#   [335] The name of the composer of The Lost Daughter is Andrew Dost.
#   [336] The name of the spouse of John Lennon is Edwin Weld Corning.
#   [337] The Silence of the Lambs follows Physical Review C, Nuclear Physics.
#   [338] The name of the composer of Moon Knight is Lindsay Lohan.
#   [339] The name of the position held by James Alexander Hamilton is king of Phrygia.
#   [340] The name of the award Jennifer Aniston won is Kyoto Shimbun Cultural Award.
#   [341] The name of the country which murder of Odin Lloyd is associated with is Vandal Kingdom.
#   [342] The place of birth of Sandra Bullock is Hochstadt am Main.
#   [343] The place of birth of Phillip Schofield is Nash County.
#   [344] The names of the siblings of Mario are Seosamh Mac Grianna.
#   [345] The name of the spouse of James R. Jordan, Sr. is Zhang You.
#   [346] The name of the anthem of India is Txuri-urdin.
#   [347] The name of the director of Veeram is Campino.
#   [348] The place of birth of Margaret Thatcher is Bojayá.
#   [349] 2021 Virginia gubernatorial election follows 1978 Carebaco Junior International Badminton Championships – men's doubles.
#   [350] The name of the country of citizenship of Mohammed bin Zayed Al Nahyan is Kurds.
#   [351] The name of the country which Michigan–Ohio State football rivalry is associated with is Tuva.
#   [352] The name of the spouse of Megan Fox is Reginald Crook, 1st Baron Crook.
#   [353] The name of the field of work of Petr Pavel is translated work.
#   [354] The place of birth of Bob Marley is Košice.
#   [355] The names of the siblings of Nikola Tesla are Peary D. Stafford.
#   [356] The name of the country of citizenship of Robert Whittaker is Dál Riata.
#   [357] The name of the father of Joe Biden is Manuel do Nascimento Vargas.
#   [358] The name of the country of citizenship of Audrey Hepburn is Nazi Germany.
#   [359] Eurovision Song Contest 2022 is followed by 2004/2005 German Badminton Championships U19 – mixed doubles.
#   [360] The name of the country of citizenship of Howard Hesseman is Guyana.
#   [361] UFC 251 follows Werner, Franz (ADB).
#   [362] The name of the country of citizenship of Ankita Lokhande is Chile.
#   [363] The name of the mother of Ted Cruz is Lady Emily Percy.
#   [364] The name of the country of citizenship of John Travolta is Kazakh Soviet Socialist Republic.
#   [365] The name of the composer of Thalaivi is Phoebe Knapp.
#   [366] The name of the country of citizenship of Karine Jean-Pierre is Kingdom of Iraq.
#   [367] The name of the spouse of Osman I is Elna Kiljander.
#   [368] 2022 FIFA World Cup qualification (CONCACAF) is followed by 1872 United States presidential election in Minnesota.
#   [369] The name of the country which Aspire is associated with is Guangxi.
#   [370] The name of the mother of Prince Edward, Duke of Kent is MacKenzie Scott.
#
# 🏆 Gold Document:
#   ID: 351
#   Text: The name of the country which Michigan–Ohio State football rivalry is associated with is Tuva.
#
# 🗳️ Choices:
#   choice_A: The Star-Spangled Banner
#   choice_B: La Marseillaise
#   choice_C: Kimigayo
#   choice_D: Tooruktug Dolgai Tañdym
#   choice_E: Jana Gana Mana
#   choice_F: God Save the King
#
# ✅ Correct Choice: choice_D → Tooruktug Dolgai Tañdym
# ================================================================================

# %%
print_sample('test', 1400)
# Out:
# ================================================================================
# 📘 Split: test | Item ID: 1400 | Query ID: 1400
# --------------------------------------------------------------------------------
# 🧠 Query:
# The name of the head of state of the country 5 Forge Row is associated with is
#
# 📚 All Documents:
#   [0] The name of the country which Goursez Vreizh is associated with is Franche-Comté.
#   [1] The name of the country which Pralayakkad South is associated with is Sui dynasty.
#   [2] The gender of Jose L Castillo is cisgender female.
#   [3] The occupation of Emily I Jones is philatelist.
#   [4] The name of the country which Suttor is associated with is Dutch Republic.
#   [5] The name of the country which canton of Orcières is associated with is Chuvash Republic.
#   [6] The occupation of G.L. Defer is Greek prefect.
#   [7] The name of the country which Shockwave is associated with is Republic of Abkhazia.
#   [8] The occupation of Nicholas D Rintala is police dog.
#   [9] The name of the mother of Stephana Warnock is Sheila Mary Nolan.
#   [10] The gender of Henry John Gepp is bigender.
#   [11] boxing at the 2010 Asian Games – men's 69 kg is followed by 1995/1996 German Badminton Championships U14 – women's doubles.
#   [12] Scania CR110 is followed by 2008 United States presidential election in Louisiana.
#   [13] The name of the position held by Thomas Phillipps Lamb is deputy high court judge.
#   [14] The name of the country which Larch is associated with is Serbia and Montenegro.
#   [15] 2041 BC follows 29668 Ipf.
#   [16] 1981 Lithuanian Badminton Championships – women's singles follows Loschge, Friedrich Heinrich.
#   [17] The place of death of Ray Wietecha is Staßfurt.
#   [18] The name of the country which Maniyakaranchalla is associated with is Crown Colony of Malta.
#   [19] The name of the country which 2012/2013 German Senior Badminton Championships O55 – women's doubles is associated with is Russian State.
#   [20] The name of the country which 81st Missouri General Assembly is associated with is Ostikanate of Arminiya.
#   [21] The name of the country which Kafr Kila is associated with is Portuguese Guinea.
#   [22] The name of the country which Menderie is associated with is Ba'athist Iraq.
#   [23] Lange, Reinerus follows 1971 Western Australian state election.
#   [24] The name of the country which Gushi culture is associated with is Spanish Guinea.
#   [25] The name of the employer of Momodou W Jallow is Athersys.
#   [26] The name of the country which Paşalı is associated with is Nigeria.
#   [27] 1991 Slovenian Badminton Championships – men's singles is followed by 15 Shevat.
#   [28] The name of the author of Caught in the trio trap? Potential selection bias inherent to association studies using parent-offspring trios. is Alfgeir L Kristjansson.
#   [29] The name of the country of citizenship of Leonardo Vinhas Ciacci is Oman proper.
#   [30] The name of the father of Massinissa of the Rif is Guy Bainbridge Norrie.
#   [31] The name of the country which Fort Peck Theater is associated with is Guatemala.
#   [32] The name of the child of Arthur Pitman Gordon is John Ligonier, 1st Earl Ligonier.
#   [33] The name of the country which 1974 Swedish Open Badminton Championships – women's doubles is associated with is Duchy of Saxe-Altenburg.
#   [34] The occupation of Frank D Verbraak is economist.
#   [35] The name of the country which Dragelji (Predograd) is associated with is Astrakhan Oblast.
#   [36] The name of the father of Huang Yangmeng is James M'Creight.
#   [37] The name of the country of citizenship of Corry A. Bushnell is Biscay.
#   [38] The name of the author of Processing of word stress related acoustic information: A multi-feature MMN study. is Charles R Tyler.
#   [39] The name of the father of Zhou Zhengzi is Toirdhealbhach Donn Ó Briain.
#   [40] 2015/2016 German Badminton Championships U17 – men's doubles follows 1366 BC.
#   [41] 1965 New Zealand Badminton Championships – women's singles follows 6th New York State Legislature.
#   [42] The name of the employer of Jesmin A Rupa is Chicago American.
#   [43] Elvers, Christian Friedrich follows 2018/2019 Sachsen Badminton Championships – mixed doubles.
#   [44] The name of the country which Lago Scuro is associated with is Saudi Arabia.
#   [45] 1868 United States presidential election in Connecticut is followed by 9127 Brucekoehn.
#   [46] The name of the country which Carrier Strike Group Fourteen is associated with is Myanmar.
#   [47] The occupation of Girdhari M Sharma is Trainer.
#   [48] The name of the country which Feldweg auf der Röhre is associated with is Mauretania.
#   [49] The name of the child of Aralt mac Sitric is Charles Saunders Skelton Dupuis.
#   [50] The name of the country which Flower Painter in Ordinary is associated with is Novorossiya.
#   [51] The name of the country which Laboratoire d'Économie des Ressources Naturelles is associated with is Autonomous Republic of Abkhazia.
#   [52] Anya Taylor-Joy/Lil Nas X follows 585-586 one-year-period.
#   [53] The name of the country of citizenship of Edward Mascall is Argentine Confederation.
#   [54] Stifter, Adalbert follows 1888 in Germany.
#   [55] The name of the country which Ankalagi is associated with is Yamataikoku.
#   [56] The name of the country which Carta Valley is associated with is Comoros.
#   [57] The name of the country which Victorian Railways Y class is associated with is People's Socialist Republic of Albania.
#   [58] The gender of Franklin D. Richards is transfeminine.
#   [59] The Boat Race 1857 is followed by Representative Men: Men of Letters: Abelard, Petrarch, the Scaligers, Herder, Gibbon.
#   [60] The name of the country of citizenship of Simon Nurme is Hittite Empire.
#   [61] The name of the country which Bungawalbin is associated with is West Timor.
#   [62] The occupation of Qin-Ying Yao is delivery stork.
#   [63] The occupation of Christopher J Burant is pickpocketing.
#   [64] The name of the country of citizenship of Stavros G. Livanos is Vatican City.
#   [65] The occupation of Hallie M Hintz is labour movement.
#   [66] 2012/2013 German Badminton Championships U17 – women's doubles is followed by 2029 Cyprus Junior Badminton Championships – women's doubles.
#   [67] The name of the father of Edward Lowes is Peregrine Osborne, 3rd Duke of Leeds.
#   [68] The name of the country which Casas Grandes is associated with is Palestinian territories.
#   [69] The name of the country of citizenship of Ernest Brooks is Vandals.
#   [70] The names of the siblings of Alix II of Dreux are Isabel of Luxembourg.
#   [71] The name of the country which Habitat Protection Area is associated with is Slovak Republic.
#   [72] The occupation of Inge A Ivens is agronomist.
#   [73] The name of the employer of Haelly M Metuge is CESNET.
#   [74] Luke Can See Her Face is followed by 묲.
#   [75] rowing at the 1987 Pan American Games – men's coxless pair follows 2018–19 PSV Eindhoven season.
#   [76] The occupation of Ildete L. Ferreira is ethicist.
#   [77] The name of the country which Academy of Canadian Cinema and Television Award for Best Animated Short is associated with is New Spain.
#   [78] The name of the employer of Jacob W Pederson is Bank of America.
#   [79] The occupation of Christos G Takoudis is Gas employee (France).
#   [80] The name of the country of citizenship of Giancarlo Scottà is Burundi.
#   [81] The place of birth of John Theophilus Lee is Gray Court.
#   [82] The gender of Kingsmill Foster Manley Power is female.
#   [83] The place of birth of Lauri Aaltonen is DeKalb County.
#   [84] The name of the country which Who are destroying peaceful protests? is associated with is First Czechoslovak Republic.
#   [85] The name of the country of citizenship of Lukas J. Musher is Ikhshidid dynasty.
#   [86] The name of the country of citizenship of Judit Román is Ternate Sultanate.
#   [87] The name of the author of Balen, Hendrik von is Carles Ribera.
#   [88] The name of the country which Bieliaki is associated with is Ming dynasty.
#   [89] The name of the country which Kangerong is associated with is Kingdom of Persia.
#   [90] The name of the country which F14 bicycle highway is associated with is Republic of Siena.
#   [91] 2007 Sri Lanka Badminton Championships – men's doubles is followed by 100th Indiana General Assembly.
#   [92] 2016 India Junior International Badminton Championships – women's doubles follows 2004 South Korea Badminton Championships – men's doubles.
#   [93] The name of the country which Ostrowo is associated with is East Pakistan.
#   [94] The name of the composer of Drei Klavierstücke, D. 946 is Martijn van Sonderen.
#   [95] The name of the country of citizenship of Takeo Ōkura is Trieste.
#   [96] The name of the country which Aditi Close is associated with is Duchy of Saxe-Meiningen.
#   [97] D♭ follows 2004 Utah gubernatorial election.
#   [98] The name of the country which Vandazhy Town is associated with is State of Vietnam.
#   [99] The name of the country which Law No. 4252 of August 10, 1963 is associated with is Odesa Oblast.
#   [100] The occupation of Meher A Ony is silviculture.
#   [101] 1814 BC follows 1989 Indonesia Open Badminton Championships – women's singles.
#   [102] The name of the country which Al Dhafra is associated with is Kingdom of the Two Sicilies.
#   [103] The name of the spouse of Heidi Blose is Sachchidananda Vatsyayan.
#   [104] The place of death of Orlando B. Willcox is Corse-du-Sud.
#   [105] The name of the country of citizenship of Darlene Maria de Moura Carvalho is Tsenacommacah.
#   [106] 1972/1973 Danish Junior Badminton Championships U17 – men's doubles is followed by 1920 United States presidential election in Arkansas.
#   [107] The name of the father of Qiu Wenxue is Edward Conyngham Denison.
#   [108] The name of the child of Thomas Soutter Lodge is Veselin Stoyanov.
#   [109] The occupation of Helmut J Böhm is HVAC.
#   [110] tetracation is followed by Fossils and Lithography Museum.
#   [111] The name of the country of citizenship of Louis Guérin is Wattasid dynasty.
#   [112] The place of birth of Abdulaziz Abo Shaqraa is Pirkkala.
#   [113] The name of the employer of Kewal K Mahapatra is Institute of Applied Astronomy.
#   [114] 2nd Georgia General Assembly follows 1980 Scottish Open Badminton Championships – men's doubles.
#   [115] The place of birth of Frédéric de Courcy is Dunwoody.
#   [116] The name of the country of citizenship of Josefin Lassinantti is Captaincy General of Cuba.
#   [117] 1960/1961 GDR Junior Badminton Championships – men's singles follows 9212 Kanamaru.
#   [118] The name of the employer of Adel R Abd-Allah is Kinsey Institute for Research in Sex, Gender, and Reproduction.
#   [119] The name of the country which Federal University of Rio de Janeiro Repository is associated with is Kingdom of Iberia.
#   [120] The occupation of Michael K Bogdos is gastroenterologist.
#   [121] The name of the country of citizenship of Darrell Opfer is East Africa Protectorate.
#   [122] 1977 in Irish television is followed by 3719 Karamzin.
#   [123] The name of the country which Middleboro Theatre is associated with is Gagauzia.
#   [124] The place of birth of John Roches is Sic.
#   [125] The name of the country of citizenship of Tetsuō Uotani is Kingdom of Commagene.
#   [126] The name of the country which Regional road 292 is associated with is Principality of Minsk.
#   [127] The name of the employer of Nicholas V Passalacqua is Sky Arts.
#   [128] The gender of Dorothy Kitson is assigned female at birth.
#   [129] The name of the country which 1876 Liskeard by-election is associated with is Dol Blathanna.
#   [130] The name of the author of Bönicke, Johann Michael is Arthur Erdélyi.
#   [131] The name of the country which Korong is associated with is Aztec Empire.
#   [132] The name of the country which 1915 Block, Albany Primary School is associated with is Colony of Aden.
#   [133] The name of the country of citizenship of Arthur Charlut is Estonia.
#   [134] The place of death of Lester Habegger is Canterbury Region.
#   [135] The name of the country of citizenship of Reinaldo Rodriguês dos Santos is Later Zhou dynasty.
#   [136] The occupation of Laura I Stirrat is reservist.
#   [137] The name of the country of citizenship of Kent Mackenzie is Kingdom of Afghanistan.
#   [138] The occupation of Jedediah H Pixley is Imperial Count.
#   [139] The name of the country which Pookod is associated with is Kingdom of Montenegro.
#   [140] The name of the country which Djiboutian franc is associated with is Mongolian People's Republic.
#   [141] The name of the mother of Christopher James Gurnhill is Sheila Lennox-Boyd.
#   [142] The name of the country which Marschel Frank Sachs AG is associated with is Croatian Republic of Herzeg-Bosnia.
#   [143] 1549 Mikko follows first inauguration of Ronald Reagan.
#   [144] The name of the country which 161028-ALMAFUERTE is associated with is Karelia.
#   [145] The name of the country which Law No. 2054 of October 31, 1953 is associated with is Crown Dependencies.
#   [146] The name of the author of Macronuclear genome sequence of the ciliate Tetrahymena thermophila, a model eukaryote is Kristin E Mull.
#   [147] The occupation of Anthony J Morgan is coauthor.
#   [148] The name of the country which Talpee is associated with is Uzbek Khanate.
#   [149] The name of the country which Polish Armed Forces is associated with is Prince-Bishopric of Utrecht.
#   [150] The name of the country which Adler- und Hirschbrauerei is associated with is Qin dynasty.
#   [151] The name of the country which Pura Taman Mumbul is associated with is Chagos Archipelago.
#   [152] The occupation of Mariah Carey is notary public.
#   [153] The name of the country of citizenship of Egnate Ninoshvili is Achaean League.
#   [154] The name of the country of citizenship of Takuji Tachi is The Gambia.
#   [155] The name of the child of Alberto Manuel Izura y Montesinos is Celia Flores.
#   [156] The name of the father of J. Douglas McDonald is Richard Benyon of Madras.
#   [157] The name of the country of citizenship of Frank Benjamin Schutt is Kingdom of Scotland.
#   [158] The name of the country which 2014–15 Sultan Qaboos Cup is associated with is Nilfgaard.
#   [159] The name of the employer of Erin E Dooley is DiDi.
#   [160] The name of the country which Great Ryton is associated with is Eritrea.
#   [161] The name of the country which Dzongkhul Monastery is associated with is Ghurid Empire.
#   [162] 1967 Pakistani Badminton Championships – women's doubles is followed by 33737 Helenlyons.
#   [163] The name of the country which Grand Theatre's Spriet Stage is associated with is Indo-Greek Kingdom.
#   [164] The name of the country which Lộc Ninh is associated with is Cape Colony.
#   [165] The name of the country which 2016 Italian Badminton Championships – men's doubles is associated with is Second Mexican Empire.
#   [166] The occupation of Smiths S Lueong is myrmecologist.
#   [167] The name of the country which 2015/2016 Danish Senior Badminton Championships O45 – men's doubles is associated with is Basque Autonomous Community.
#   [168] The name of the child of Władysław Sikorski is Enoch Agnew.
#   [169] The name of the country which PS-65 Hyderabad-IV is associated with is Gojoseon.
#   [170] The name of the director of The Last Tightrope Dancer in Armenia is Micheline Lanctôt.
#   [171] The name of the country which Milagrosa is associated with is Meghalaya.
#   [172] The name of the country which Nigeria–Slovenia relations is associated with is Ivanovo Oblast.
#   [173] The name of the employer of Paul W Dunk is Florida Hospital Cancer Institute.
#   [174] The name of the country which 2011–12 Scottish Premier Under-19 League is associated with is Eldiguzid state.
#   [175] The name of the country which Rectangular earthwork enclosure in Hill Wood, 650m south east of Grimsdyke Farm is associated with is Omsk Oblast.
#   [176] The name of the employer of Anuj K Dalal is International Center for Tropical Agriculture.
#   [177] The name of the country of citizenship of Abu Taher Mohammad Haider is General Government.
#   [178] The name of the child of Wyndham Carlyon Madden is Charlotte Baird.
#   [179] The name of the country which 2025 Norwegian Badminton Championships U15 – women's doubles is associated with is Duchy of Warsaw.
#   [180] 2023 Israel Junior International Badminton Championships – women's singles follows 2008/2009 German Badminton Championships U17 – women's doubles.
#   [181] The names of the siblings of Ajmal Khan are Francisco Martínez Villacañas.
#   [182] The place of birth of Hardy Caprio is Coles County.
#   [183] Du Mont, Marcus Theodor is followed by Final Mission.
#   [184] The name of the country which Hacettepe University Sıhhiye Campus is associated with is Brokilon.
#   [185] The occupation of Juan Fonseca Bueno is wirefitter.
#   [186] The name of the country which Oracle View Cinemas is associated with is Asgardia.
#   [187] The name of the mother of Katharine Savile is Louisa Catherine Adams Johnson.
#   [188] The name of the author of Chicxulub impact ejecta deposits in southern Quintana Roo, México, and central Belize is Michel Cassé.
#   [189] The name of the country which Taki Rua Production of the Year is associated with is Province of Quebec.
#   [190] The name of the country which Buildings of Gamboa is associated with is Johor.
#   [191] The name of the country which 2009 Mitsubishi Electric Europe Cup – singles is associated with is Kaduna State.
#   [192] The place of birth of János Mócsy is Deniliquin.
#   [193] The name of the father of Sofya Konstantinova is Sir John Pringle, 5th Baronet.
#   [194] The name of the country which Longoria is associated with is Bermuda.
#   [195] The name of the country which 118, All Saints Street is associated with is Achaemenid Empire.
#   [196] The name of the country which Charlbury is associated with is People's Republic of Bulgaria.
#   [197] The occupation of Tahar Bajjou is editor.
#   [198] 2003 India Junior Badminton Championships – men's singles follows 2009 Macau Junior Badminton Championships – women's doubles.
#   [199] The name of the country which Shah Abbasi Caravanserai of Abbasabad is associated with is Vladimir Oblast.
#   [200] The name of the country of citizenship of Thankamani Gopinath is Spanish Protectorate in Morocco.
#   [201] 1983 Swiss Junior Badminton Championships – women's singles is followed by Wibmer, Karl August.
#   [202] The gender of unknown Steel is muxe.
#   [203] The name of the country which Jot Em Down is associated with is Beylik of Hamid.
#   [204] 2023 Israel Badminton Championships – women's singles is followed by 10th Michigan Legislature.
#   [205] The name of the country of citizenship of Robert J. Burch is Tuʻi Tonga Empire.
#   [206] The name of the country which Ferreirós, Vila de Cruces is associated with is Archbishopric of Salzburg.
#   [207] August Friedrich, Prinz von Braunschweig is followed by 1984 Japan Open Badminton Championships – men's doubles.
#   [208] The occupation of Andrea M Fetters is secondary school.
#   [209] The name of the country which Institut Teknologi & Sains Nahdlatul Ulama is associated with is Ubangi-Shari.
#   [210] The name of the country which Dublin MRA is associated with is Costa Rica.
#   [211] The name of the country of citizenship of Aleksandra Buvanova is Lesotho.
#   [212] The occupation of Mary Decker is costume designer.
#   [213] The name of the country which Salierplatz is associated with is Liepāja.
#   [214] The name of the country of citizenship of Gérard Lespinasse is California Republic.
#   [215] The name of the country which Variation Reduction Solutions (United States) is associated with is Buryatia.
#   [216] The name of the country which Studio Movie Grill Arena Grand is associated with is Liberland.
#   [217] The name of the country which Naylor Airport is associated with is Ethiopian Empire.
#   [218] The name of the country which Sezione di Archivio di Stato di Termini Imerese is associated with is Dacia.
#   [219] The gender of Graeme Warren Kidd is demiboy.
#   [220] 2018–19 LEN Euro Cup follows Habítame siempre.
#   [221] The name of the country which Faculté des Sciences de la Santé is associated with is Wuyue.
#   [222] The name of the country which Lahor is associated with is Ancient Elis.
#   [223] The occupation of Léontine Goirand is spiritualist.
#   [224] The name of the author of Using stem cell-derived gametes for same-sex reproduction: an alternative scenario is Binghang Liu.
#   [225] The name of the author of Alle tot nu toe bekende schilderijen van Rubens (Vol. 1) is Antoine G Sreih.
#   [226] The name of the country which Bookplate: Taiwan, street, staircase, coffee shop, shop sign, lantern, Jiufen is associated with is Kenya Colony.
#   [227] The name of the country which Venten Management is associated with is Italian Social Republic.
#   [228] The name of the country which Hot Sports Arena is associated with is Colony of Vancouver Island.
#   [229] The name of the country of citizenship of Blake Ostler is Baku Commune.
#   [230] The name of the country which San Diego Science Center is associated with is Viceroyalty of Peru.
#   [231] The name of the country which Coast Guard Good Conduct Medal is associated with is Kingdom of Kent.
#   [232] The names of the siblings of Julius von Zwiedinek-Südenhorst are Maria of Navarre.
#   [233] The name of the country which SIBGRAPI 2007, XX Brazilian Symposium on Computer Graphics and Image Processing, Belo Horizonte, Brazil, 7-10 October 2007 is associated with is New France.
#   [234] The name of the father of Ji Rushen is Gösta Ekman.
#   [235] 18 Jumada al-awwal follows Raue, Christian.
#   [236] The name of the country which [Letter Concerning the Distribution of Books in Hong Kong] is associated with is Maldives.
#   [237] The name of the country which Cerro Gordo Landing is associated with is Vanuatu.
#   [238] The name of the author of Indeterminate Human Immunodeficiency Virus Type 1 Western Blots: Seroconversion Risk, Specificity of Supplemental Tests, and an Algorithm for Evaluation is William J Brady.
#   [239] The occupation of Hamidreza Mani is exhibit.
#   [240] The name of the country which Stetson Historical Society, Maine is associated with is Southern Netherlands.
#   [241] The occupation of Subrata K Pore is travel guide.
#   [242] The name of the country which Sluneční is associated with is Wisconsin.
#   [243] The name of the child of Xu Suizhong is Richard Hill, 7th Baron Sandys.
#   [244] The occupation of Regina Reimann is quaternary geology.
#   [245] The place of birth of Voitto Liukkonen is Concise.
#   [246] The name of the country which 2009 Bangladesh Badminton Championships – men's singles is associated with is Benin.
#   [247] The name of the author of SCAPIN-82: Radio Designating Hakodate As Principal Port And Otaru As Alternate is Christopher Sells.
#   [248] The name of the country which Hialeah Theatre is associated with is Cispadane Republic.
#   [249] The name of the mother of William Berry is Hannah Curtis.
#   [250] The name of the child of Walter Whitfield is Bertram Robert Stewart.
#   [251] The name of the country which St Magnus Cathedral, Kirkwall is associated with is Saint Barthélemy.
#   [252] The name of the country of citizenship of Hector Fautario is Bhopal State.
#   [253] The name of the country which , is associated with is Kingdom of Serbs, Croats and Slovenes.
#   [254] The name of the country which Bookplate: flower, circle is associated with is French protectorate of Tunisia.
#   [255] The occupation of Peter M. Chumakov is Yosemite National Park.
#   [256] The name of the country which Puthusserikkunnu is associated with is The Protectorate.
#   [257] The occupation of Heidi E Kosiorek is three-cushion billiards.
#   [258] 21530 Despiau follows 1964 Swiss Open Badminton Championships – men's singles.
#   [259] The name of the spouse of Janet Macdougall is Trinidewi Lasuki.
#   [260] The name of the father of James Allan Beau is Kenelm Winslow.
#   [261] The name of the country which 1949–50 Welsh Cup is associated with is Socialist Federal Republic of Yugoslavia.
#   [262] The name of the child of Charles Kinnaird Johnstone-Gordon is Lyla Gilman.
#   [263] The name of the country which East Redmond is associated with is Melniboné.
#   [264] The name of the author of Job strain in relation to ambulatory blood pressure, heart rate, and heart rate variability among female nurses. is Emmanuel C Opara.
#   [265] 1848 United States House of Representatives elections is followed by 2000 Swiss Junior Badminton Championships – men's singles.
#   [266] 1968 United States presidential election in Florida is followed by Stunz, Joseph Hartmann.
#   [267] The name of the author of MitoAge: a database for comparative analysis of mitochondrial DNA, with a special focus on animal longevity is Kurt B Nolte.
#   [268] The occupation of Robin R High is Indian Railways.
#   [269] 즊 is followed by 2018 Italian International Badminton Championships – women's singles.
#   [270] The name of the position held by Rombertus van Uylenburgh is Ohio Secretary of State.
#   [271] ThrustSSC is followed by David, Ferdinand.
#   [272] 1465-1466 one-year-period follows Member of the 1614 Parliament.
#   [273] 11752 Masatakesagai is followed by Beger, Eusebius.
#   [274] The occupation of Denise M Nogueira is haiku poet.
#   [275] The name of the country which Aizu Railway AT-700 series is associated with is French Upper Volta.
#   [276] The name of the country which Radioactive Substances Act 1993 is associated with is Grand Duchy of Hesse.
#   [277] The name of the country which Batu Sapi Secondary School is associated with is Socialist Republic of Montenegro.
#   [278] The occupation of Prashant K Mallick is logging.
#   [279] The occupation of Maximiliano Gelli is Alchemy.
#   [280] The name of the country which Pathirippadam is associated with is Democratic Republic of Afghanistan.
#   [281] The name of the father of Herbert Philip Deedes is Otto von Schonauwen.
#   [282] The name of the mother of John Lethbridge is Infanta Maria Adelaide of Portugal.
#   [283] The name of the country which Anyar is associated with is Liang dynasty.
#   [284] The occupation of Neelam R Yadav is tarotologist.
#   [285] The name of the country which 79th Oregon Legislative Assembly is associated with is Arab Kingdom of Syria.
#   [286] The name of the country of citizenship of Sharad Saboo is Cherokee Nation.
#   [287] 1895 European Rowing Championships – men's single scull is followed by 2010 Denmark Open Badminton Championships – men's doubles.
#   [288] The name of the country which Shanghai Civil Aviation College is associated with is Dutch Caribbean.
#   [289] 먜 is followed by 1993 South Korea Badminton Championships – men's doubles.
#   [290] The name of the screenwriter of Masangeles is Jacques Tati.
#   [291] The name of the country which Asian Library Resources of Australia is associated with is Chiles volcano.
#   [292] The name of the country of citizenship of Ed Mooney is First Republic of Austria.
#   [293] The place of birth of Nate Darling is Halachó Municipality.
#   [294] The name of the country which Ulvozh is associated with is Spocania.
#   [295] 2019 Belarus Badminton Championships – men's doubles follows 1934 Paris-Tours.
#   [296] The name of the country which Ecclesiastical Commissioners (Powers) Measure 1942 is associated with is Company rule in India.
#   [297] Everything Is Forgotten follows 9340 Williamholden.
#   [298] The occupation of Alexander S Cheung is Inspector general for French Social Affairs.
#   [299] Heidler, Karl Joseph follows 7623 Stamitz.
#   [300] The name of the country which Huilong is associated with is Maratha Empire.
#   [301] The name of the country which Nisa Ntodo is associated with is Bahrain and its Dependencies.
#   [302] The occupation of Laurel O Sillerud is Benshi.
#   [303] The place of death of Elizabeth Mortimer is Budapest District IV.
#   [304] The name of the country of citizenship of Sydney Coulson is Gourdon.
#   [305] The name of the spouse of Philip Ivor Caleb is Zhang Weiyue.
#   [306] The name of the country which Dukes Bridge is associated with is Sweden-Finland.
#   [307] The name of the country which Law-decree No. 1288, of May 24, 1939 is associated with is Arab Caliphate.
#   [308] The name of the country which Sri Narayan Vidyabhaban Boys' High School is associated with is Taifa of Zaragoza.
#   [309] The name of the country which Goxhill is associated with is Dʿmt.
#   [310] The place of birth of Ruymán Hernández is Surxondaryo.
#   [311] The name of the country which Garretson Woodruff & Pratt is associated with is Sápmi.
#   [312] The name of the country which Locust Mount is associated with is Principality of Reuss-Gera.
#   [313] 2008 Greece Junior Badminton Championships – women's singles follows 2019 Norwegian Badminton Championships – men's doubles.
#   [314] The name of the father of Arthur Pelham is Philip Fletcher.
#   [315] The occupation of Christopher T Laird is podestà.
#   [316] The name of the country which Empresa Nacional del Petróleo is associated with is Commonwealth of the Philippines.
#   [317] The occupation of Sydney N Newsom is slave owner.
#   [318] The place of death of Emanuil Aizikovich Kaner is Zone 9 of Milan.
#   [319] The name of the country which Dzidzi is associated with is Federated States of Micronesia.
#   [320] The name of the country which 1957/1958 Durham Open Badminton Championships – mixed doubles is associated with is Allied-occupied Germany.
#   [321] The name of the country of citizenship of Hisaharu Saito is Kingdom of Iraq.
#   [322] The name of the country which Bhowanipore is associated with is Barbados.
#   [323] The name of the country which Chalfont & Latimer station is associated with is Tanzania.
#   [324] The occupation of Emily M Lawton is production.
#   [325] The Smothers Brothers/Big Country is followed by 2019 Rolex Shanghai Masters – singles.
#   [326] The place of death of Digvijay Nath is Isla Cristina.
#   [327] The name of the country which Vép is associated with is Đại Việt.
#   [328] 2022 Slovak Junior Badminton Championships – women's doubles is followed by Goblin Slayer: Goblin's Crown.
#   [329] The name of the country which Namibia University of Science and Technology is associated with is Beylik of Aydın.
#   [330] The name of the country which 66th Missouri General Assembly is associated with is First Saudi State.
#   [331] The name of the country which Goldfields West is associated with is Taebong.
#   [332] The name of the employer of Pasquale Migliozzi is Maulana Abul Kalam Azad University of Technology, West Bengal.
#   [333] 1993 Danish Badminton Championships – women's singles is followed by 720 Bohlinia.
#   [334] The name of the country which 2008 Channel One Cup is associated with is Pingtung County.
#   [335] The name of the author of New data clarifying the taxonomy of European members of the Lepidocyrtus pallidus–serbicus group (Collembola, Entomobryidae) is Suneel C Mundkur.
#   [336] The name of the mother of Margus Hernits is Dolores Gage.
#   [337] The name of the country of citizenship of Roger Alisson Viegas Barbosa is Nazi Germany.
#   [338] The name of the country of citizenship of Kōta Kawaguchi is New Zealand.
#   [339] The name of the country which Wijaya Kusuma is associated with is Augsburg.
#   [340] The name of the country which Meadowcrest is associated with is Albanian Republic.
#   [341] The name of the country which Keelung Fairy Cave is associated with is Yobe State.
#   [342] The name of the director of Friday Night's Alright for Fighting is Shinji Takamatsu.
#   [343] The name of the country which Meridian Drive-In is associated with is Republic of Texas.
#   [344] The name of the country which Rehoboth is associated with is Southern Cameroons.
#   [345] The occupation of Samanta S Mattos is State Historic Preservation Officer.
#   [346] The name of the country which Dům dětí a mládeže Praha 8 - Spirála is associated with is Southern Ireland.
#   [347] The occupation of Chinwe U Chukwudi is record production team.
#   [348] The name of the country of citizenship of John Tiffin Stewart is Rohingya.
#   [349] The name of the country which 1st Cavalry Division Sustainment Brigade is associated with is Baol.
#   [350] Weinsberg, Hermann von is followed by 됌.
#   [351] The occupation of Mohamed E Elsayed is Dungeon Master.
#   [352] 11th Oklahoma Legislature is followed by 2018 Lingshui China Masters – mixed doubles.
#   [353] 23689 Jancuypers follows 14834 Isaev.
#   [354] 2020/2021 Primera División de Bádminton is followed by 2012/2013 Indian Badminton Championships – mixed doubles.
#   [355] The name of the employer of Chris S Mantsounga is Earth and Planetary Exploration Services.
#   [356] The name of the mother of Edward John William Malindine is Julienne Mathieu.
#   [357] 1933 BC is followed by 8455 Johnrayner.
#   [358] The name of the country which Maradun II is associated with is Ürümqi.
#   [359] The name of the father of Gao Yifeng is Niitabe-shinnō.
#   [360] The name of the country which Burlington Heights is associated with is Islamic State of Afghanistan.
#   [361] The name of the country which Leyden is associated with is Kushan Empire.
#   [362] The name of the country which 2013 Arimex Challenger Trophy – singles is associated with is Valais.
#   [363] 5881 Akashi is followed by 49469 Emilianomazzoni.
#   [364] The occupation of Stephen Mounce is 3-cushion player.
#   [365] Jeep Wrangler (JL) follows 2012/2013 Danish Senior Badminton Championships O60 – mixed doubles.
#   [366] The name of the country of citizenship of Artem Suschko is Val d'Aran.
#   [367] The name of the country which Tobré is associated with is Kingdom of Abkhazia.
#   [368] The name of the spouse of Angela Margaret Manners is Constance of Greater Poland.
#   [369] The name of the country which Sambramam is associated with is French Guinea.
#   [370] The name of the author of Backbone assignments of the 26 kDa neuron-specific ubiquitin carboxyl-terminal hydrolase L1 (UCH-L1). is Rayko I Stantchev.
#   [371] The occupation of Pavel P Kuksa is editorial columnist.
#   [372] Kirsch, Georg Wilhelm is followed by 23060 Shepherd.
#   [373] The name of the country which A.O. Shirley Recreation Ground is associated with is South Tyrol.
#   [374] The name of the country which Nature reserve zone in Regional Park is associated with is Roman Britain.
#   [375] The name of the employer of Sean P.S. Gulick is Clinica de Salud del Valle de Salinas.
#   [376] The name of the employer of Joseph A. Russell is Office of Price Administration.
#   [377] The name of the author of March Trilogy is José María Gironella.
#   [378] The occupation of Vittorio Vellani is gambling.
#   [379] The occupation of Rachel M. Keen is retail.
#   [380] The name of the country of citizenship of Chrēstos S. Solomōnidēs is Hoysala Empire.
#   [381] The name of the country of citizenship of Ailton Gomes da Silva is Goryeo.
#   [382] 2014 Australian Open Badminton Championships – men's doubles follows Pfeiffer, Johann Friedrich von.
#   [383] The name of the country which Northwoods Beach is associated with is Duchy of Brunswick.
#   [384] The name of the country which 5 Forge Row is associated with is Bhutan.
#   [385] The name of the employer of Bart J Bruin is American Optical.
#   [386] The occupation of Josephine R Coury is Riksråd.
#   [387] The name of the country which Cuyín Manzano is associated with is July Monarchy.
#   [388] The name of the country which Society for Indonesian Biodiversity is associated with is Canary Islands.
#   [389] The name of the father of Helena Benešová Šustrová is Xiang Huan.
#   [390] 2009 Swedish International Stockholm – men's doubles is followed by 2004 Croatian Badminton Championships – women's singles.
#   [391] Hedwig, Johann follows 2002 World Rowing Under 23 Regatta – U23 men's quad scull.
#   [392] The name of the architect of Morris Marks House is Frigyes Feszl.
#   [393] The name of the father of Catherine Amanda Coburn is Angelo Pullen.
#   [394] Journals of the House of Commons Volume 200 is followed by 2010 Canadian International Badminton Championships – men's doubles.
#   [395] The place of death of Philippe Maximilien de Merode, Marquis de Westerloo is Ténès.
#   [396] The name of the employer of Ganesh N Nawale is Brothers Dalziel.
#   [397] The name of the country which Moss Vale Library is associated with is Tokelau.
#   [398] The name of the country which Fielding is associated with is New Hampshire.
#   [399] The name of the country which Bio-Medical Science (South Korean) is associated with is Duchy of Guastalla.
#   [400] The name of the country which Broadway and Longton East is associated with is Roman Republic.
#   [401] The occupation of Shelby A Armstrong is Musketeers of the Guard.
#   [402] The name of the country which Royal Question is associated with is Tanganyika.
#   [403] The occupation of Kris A Murray is acharya.
#   [404] The name of the spouse of Gheorghe Tătărescu is Bendor Grosvenor.
#   [405] The name of the country which Chang Sheng Cun is associated with is Confederate States of America.
#   [406] The name of the country which Islamic Azad University of Saveh is associated with is Sudan.
#   [407] The name of the spouse of Deborah (?) is Nikos Poulantzas.
#   [408] The name of the mother of Alex Eisenhower is Ingrid of Sweden.
#   [409] The name of the country which Special Rapid Response Detachment is associated with is Republic of Ragusa.
#   [410] The occupation of Wisam E Mohammed is Russian Academy of Sciences.
#   [411] The name of the country which 1975 Portugal Badminton Championships – women's doubles is associated with is Primorsky Krai.
#   [412] The occupation of Steve J Melnick is bomb disposal.
#   [413] The occupation of Mohamed A Mahmoud is freight forwarder.
#   [414] The name of the country which Nottanalakkal is associated with is Madagascar.
#   [415] The name of the country which Walaluuks Creek is associated with is Akrotiri and Dhekelia.
#   [416] The name of the author of Understanding psychiatric disorder by capturing ecologically relevant features of learning and decision-making. is Azza S El-Demerdash.
#   [417] The name of the employer of Brent D Wainwright is Institute of Psychiatry and Neurology in Warsaw.
#   [418] The name of the country which Otemma Glacier is associated with is British Raj.
#   [419] 1968 United States Senate election in Arizona is followed by 2008 Malaysia International Badminton Championships – mixed doubles.
#   [420] The occupation of Nada S Aboelella is environmental journalist.
#   [421] The name of the country which Achada de Santo António is associated with is Isle of Man.
#   [422] The name of the country which Kementerian Sosial RI is associated with is Nenets Autonomous Okrug.
#   [423] The name of the author of The nipah virus fusion protein is cleaved within the endosomal compartment. is Toshio Sato.
#   [424] The name of the country which Kosofe I is associated with is socialist state.
#   [425] The name of the country which OYO 3118 Maxi Budget is associated with is County of Aragon.
#   [426] The name of the country which Bentown is associated with is Italian Somaliland.
#   [427] The name of the country of citizenship of Pradeep Kumar is Verdis.
#   [428] Western Washington University College of Science and Technology is followed by Delicious Party Pretty Cure.
#   [429] The name of the employer of David Hernández-Pinilla is Tuenti.
#   [430] The name of the child of Charles Thorpe England is Emilie Ullerup.
#   [431] The place of birth of Josefa Celsa Señaris is Apastovsky District.
#   [432] The names of the siblings of Edmund Royds are Mária Zipernovszky.
#   [433] 121236 Adrianagutierrez is followed by Fürstenberg, Karl Egon Fürst zu.
#   [434] The name of the country which East Alburgh is associated with is Ingushetia.
#   [435] The name of the country which SR CC class is associated with is French Somaliland.
#   [436] 꾚 is followed by Grothusen, Johann.
#   [437] The name of the country of citizenship of Dai Kasahara is Kingdom of Chenla.
#   [438] The name of the country which 2023 Australian Open Badminton Championships – women's singles is associated with is German New Guinea.
#   [439] The name of the composer of La ventosa / La fortuna ha le mutande rosa is Florence Welch.
#   [440] The occupation of Gallyas F Jr is environmental anthropologist.
#   [441] The name of the award Muhammad of Negeri Sembilan won is German Research Foundation.
#   [442] The place of burial of Marisa Chiazzese is Monaco.
#   [443] 1675-1676 one-year-period is followed by 57th Oregon Legislative Assembly.
#   [444] 286 BC follows equestrian at the 2012 Summer Olympics – team dressage.
#   [445] The name of the child of Howarth Seymour Walkey is Victoria Stapleton.
#   [446] The name of the country which XHTGAN-FM is associated with is Pará.
#   [447] The occupation of Robert O Dillman is police academy.
#   [448] The name of the spouse of Victor Crutchley is Harold Stanley Cayzer.
#   [449] The name of the director of The Frog Kingdom 2: Sub-Zero Mission is Dani Levy.
#   [450] The name of the country which Federal Government College, Wukari is associated with is Slovakia.
#   [451] The name of the country which E.O. Grosvenor House is associated with is Principality of Pereyaslavl.
#   [452] 901-902 one-year-period is followed by 20302 Kevinwang.
#   [453] The name of the country of citizenship of Martin Labaška is Guadeloupe.
#   [454] The name of the country of citizenship of Auville Wright Putnam is Province of Saxony.
#   [455] The name of the country which .中国 is associated with is Project Gutenberg.
#   [456] The name of the country of citizenship of Hannchen Alde is Demak.
#   [457] The name of the country which The Ram Inn is associated with is Holy Roman Empire.
#   [458] The occupation of Phillip G Durham is social activist.
#   [459] The name of the country which Barrymore Theatre is associated with is Đắk Lắk.
#   [460] The name of the country which Kampong Tanajor is associated with is County of Portugal.
#   [461] The name of the country which Beijing Subway SFM05 is associated with is Palestinian National Authority.
#   [462] The name of the country which Sädleneggweg is associated with is Roman Palestine.
#   [463] weightlifting at the 1992 Summer Olympics – men's 67.5 kg follows 1989 World Rowing Championships – lightweight women's single scull.
#   [464] The name of the country which Cooksburg is associated with is Ancient Egypt.
#   [465] The name of the field of work of Shepard Fairey is Heteroptera.
#   [466] The name of the country which list of lighthouses in Peru is associated with is Duchy of Oldenburg.
#   [467] The name of the author of Syringomyelia associated with spinal arachnoiditis treated by partial arachnoid dissection and syrinx-far distal subarachnoid shunt. is Brynmor Haskell.
#   [468] 1989 Belgian Junior Badminton Championships – mixed doubles is followed by 1942 US Badminton Championships – mixed doubles.
#   [469] The occupation of Vinayak K Nahar is Royal Moroccan Air Force.
#   [470] The name of the employer of Santosh K Tiwari is Golden Rule Insurance Company.
#   [471] The name of the author of Gandhiji O Bhasha Samasya is Laura E Finch.
#   [472] Landerer, Maximilian Albert follows 1er Bataillon, Royal 22e Régiment.
#   [473] The name of the child of Agnès de Tailhac is Andrew James McMichael.
#   [474] The name of the child of Marie Schleissnerová is Zang Qiong.
#   [475] The name of the country which 2013 Open GDF Suez de Touraine – doubles is associated with is Kievan Rus'.
#   [476] The name of the country of citizenship of Jiri Keronen is Colony of Jamaica.
#   [477] Eclipse Aviation is followed by 2018 Czech Junior Badminton Championships.
#   [478] 1993 Gibraltar Badminton Championships – mixed doubles follows 69231 Alettajacobs.
#   [479] 107054 Daniela follows SCAPIN-57: Administration Of Affairs In Southern Korea.
#   [480] The name of the mother of Lisa Frances Haskel is Dorji Wangmo.
#   [481] The name of the country which Wureh is associated with is Hispaniola.
#   [482] The name of the country which K lázním is associated with is Portuguese Empire.
#   [483] The name of the country which New Burlington Mews is associated with is Samoa.
#   [484] The name of the country which Gieddečohkka is associated with is Paris Commune.
#   [485] The place of death of Thomas Kington is Hamblen County.
#   [486] The name of the country which Brook Hill South is associated with is Lyria and Rivia.
#   [487] The name of the country which Ettekkar is associated with is British Guiana.
#   [488] The name of the country which Bar Kham is associated with is Latvia.
#   [489] The occupation of Kelly M Gutpell is teamster.
#   [490] The name of the country which Albritton Airport is associated with is Abia State.
#   [491] The name of the employer of Stephen Southworth is National Bureau of Agricultural Insect Resources.
#   [492] The name of the position held by Xiang Yu is educator.
#   [493] The name of the mother of Lucia Agar-Ellis is Elisabeth Clarkson.
#   [494] The name of the country which 3. Liga is associated with is North Ossetia–Alania.
#   [495] 2018–19 Gabon Championnat National D1 follows 2017 Czech Junior Badminton Championships.
#   [496] The name of the author of Beginnings of medical education in and near Chicago is Mark F Spencer.
#   [497] The name of the country which Palliyarakavu Ward is associated with is Galicia.
#   [498] 1996 Adams follows 1938 in Norwegian football.
#   [499] The name of the mother of Sisir Kumar Sinha is Isabella MacDonald.
#   [500] The name of the spouse of Peter Campbell-Canney is Tamara Moskvina.
#   [501] The name of the father of Joseph Lowe is Oskar Wasastjerna.
#   [502] The name of the country which 1962/1963 West German Regional Badminton Championships – women's doubles is associated with is Eighteenth Dynasty of Egypt.
#   [503] The name of the country of citizenship of Hasmik Zhamkochyan is Kingdom of Lombardy–Venetia.
#   [504] The name of the employer of Hatem S Abbass is Peace Research Institute Oslo.
#   [505] 2009 Dutch Junior Badminton Championships – mixed doubles follows 8423 Macao.
#   [506] The name of the father of William Feilding, 3rd Earl of Denbigh is Gisulf I of Friuli.
#   [507] The place of birth of Arthur Foulkes is Crawford County.
#   [508] 2024 Estonian Junior Badminton Championships – men's singles is followed by Schmidl, Ulrich.
#   [509] 859-860 one-year-period follows Samsung Galaxy S III.
#   [510] The name of the country of citizenship of Antoinette Carinus-Holzhausen is Northern Zhou.
#   [511] 92389 Gretskij is followed by The Way We Was.
#   [512] The occupation of Natalia A Prado is dominican friar.
#   [513] The name of the country which 1956 Canadian Badminton Championships – women's doubles is associated with is Ivory Coast.
#   [514] The name of the country which Punnassery is associated with is Dutch Brazil.
#   [515] The name of the country of citizenship of John LaHood is Duchy of Magdeburg.
#   [516] 1841 Mississippi Census is followed by Air Mobility Command.
#   [517] 2007 Vietnam International Badminton Championships – mixed doubles follows 1978 US Badminton Championships – mixed doubles.
#   [518] The name of the spouse of Mitzi E. Newhouse is Ion James Muirhead Williams.
#   [519] The occupation of Ana D Goode is permaculture.
#   [520] The name of the country of citizenship of Aleksandre Koberidze is French Indochina.
#   [521] The name of the country which gymnastics at the 2011 Pan American Games – women's artistic team all-around is associated with is Pandya dynasty.
#   [522] transit of Venus, 1874 follows 90713 Chajnantor.
#   [523] The name of the country which ERF Plus is associated with is Principality of Ansbach.
#   [524] The name of the employer of Leslie J. Bank is Organisation Todt.
#   [525] The occupation of Ibeawuchi K Enwereuzor is hydrology.
#   [526] The occupation of Katharina J Huber is echinodermologist.
#   [527] 250-251 one-year-period follows 1984 United States presidential election in Oregon.
#   [528] The name of the country of citizenship of William Pratt is French Sudan.
#   [529] The name of the country which Forgetting You is Like Forgetting My Heart DOL-000476 is associated with is Mari El.
#   [530] The name of the country which SŠ oděvního designu Kateřinky-Liberec is associated with is Rostov Oblast.
#   [531] The name of the country which DWHQ is associated with is Central African Republic.
#   [532] straight-three is followed by 뱪.
#   [533] 1988 Peru Badminton Championships – mixed doubles follows 2009 World Senior Badminton Championships O35 – men's singles.
#   [534] The name of the country which 11th Asia-Pacific Conference on Conceptual Modelling, APCCM 2015, Sydney, Australia, January 2015 is associated with is Uzbekistan.
#
# 🏆 Gold Document:
#   ID: 0
#   Text: The name of the country which Goursez Vreizh is associated with is Franche-Comté.
#
# 🗳️ Choices:
#   choice_A: Willem-Alexander
#   choice_B: Charles III
#   choice_C: Naruhito
#   choice_D: Emmanuel Macron
#   choice_E: Xi Jinping
#   choice_F: Jigme Khesar Namgyel Wangchuck
#
# ✅ Correct Choice: choice_A → Willem-Alexander
# ================================================================================

# %% [markdown]
# ## 🔎 Section 3 — Implement the Retriever
#
# In this section, you have to implement a **retriever** that retrieves the most relevant documents for every query.
# You can choose to use either:
#
# - **BM25** — a lexical retriever based on token overlap, or
# - **Bi-encoder** — a neural retriever that uses **sentence embeddings**.
#
# > 💡 Read more about different types of model-based retrievers here: [blog](https://blog.dailydoseofds.com/p/visual-guide-to-bi-encoders-cross)
#
# Each retriever computes **similarity scores** between every pair of query and document.
# For each query, your goal is to identify the **top-k documents** with the highest similarity scores.

# %% [markdown]
# ### 🧩 Step 1 – Fill the missing code.
#
# Fill in the `<fill block> ... </fill block>` section in the code cells below to:
#
# 1. Compute a similarity score matrix of shape **[num_queries, num_documents]**.
# 2. Retrieve **top-k** documents per query (and optionally their similarity scores).

# %%
def get_similarity_scores(retrieval_dataset, retriever_type="model", model_name="hkunlp/instructor-large"):
    queries = [item["query"] for item in retrieval_dataset] # queries.
    documents = retrieval_dataset[0]["all_documents"] # documents.
    for idx in range(len(retrieval_dataset)): # documents for different queries in a split are exactly same.
      assert retrieval_dataset[idx]["all_documents"] == documents

    if retriever_type == 'model':
      print(f"Using retriever type: {retriever_type}, model name: {model_name}")
    else:
      print(f"Using retriever type: {retriever_type}")

    if retriever_type == "model":
        # Use the SentenceTransformer specified by model_name to compute similarity scores (tensor of shape [len(queries), len(documents)]).
        # <fill block>
        st_model = SentenceTransformer(model_name)
        doc_emb = st_model.encode(documents, convert_to_numpy=True, normalize_embeddings=True, show_progress_bar=False)
        query_emb = st_model.encode(queries, convert_to_numpy=True, normalize_embeddings=True, show_progress_bar=False)

        doc_t   = torch.from_numpy(doc_emb).float()    # [D, dim]
        query_t = torch.from_numpy(query_emb).float()  # [Q, dim]
        similarity = query_t @ doc_t.T                  # [Q, D]
        # </fill block>

    elif retriever_type == "bm25":
        # Use the BM25Okapi to compute similarity scores (tensor of shape [len(queries), len(documents)]).
        # <fill block>
        def tok(x):
            return re.findall(r"\w+", x.lower())

        tokenized_docs = [tok(d) for d in documents]
        bm25 = BM25Okapi(tokenized_docs)

        rows = []
        for q in queries:
            scores = bm25.get_scores(tok(q))
            rows.append(torch.tensor(scores, dtype=torch.float32))
        similarity = torch.stack(rows, dim=0)           # [Q, D]
        # </fill block>

    else:
        raise ValueError(f"Unknown retriever type: {retriever_type}")

    # --- Output consistency checks ---
    assert isinstance(similarity, torch.Tensor)
    assert similarity.shape[0] == len(queries) and similarity.shape[1] == len(documents)
    return similarity

# %%
def get_topk(similarity, documents, k):
    """
    Return top-k indices and documents per query for a single k.
    """
    # Use tensor manipulation to fetch indices of top-k most similar documents corresponding to each query.

    # <fill block>
    topk_indices = torch.topk(similarity, k=k, dim=1).indices.cpu().tolist()  # [[i1..ik], ...]
    topk_docs = [[documents[j] for j in row] for row in topk_indices]
    # </fill block>


    # --- Output consistency checks ---
    assert len(topk_indices) == similarity.size(0), (
        f"Mismatch: got {len(topk_indices)} query results, expected {similarity.size(0)}"
    )
    assert all(len(row) == k for row in topk_indices), "Each query must return exactly k indices"
    assert all(len(row) == k for row in topk_docs), "Each query must return exactly k docs"
    assert len(topk_docs) == len(topk_indices), "Mismatch between indices and docs output lengths"
    assert all(isinstance(idx, int) for row in topk_indices for idx in row), \
        "All elements in topk_indices must be integers"
    assert all(isinstance(doc, str) for row in topk_docs for doc in row), \
        "All elements in topk_docs must be strings"
    return topk_indices, topk_docs

# %%
def hitrate_at_k_from_indices(topk_indices, gold_ids):
    """
    Compute hit-rate@k given top-k indices (per query) and gold doc IDs (per query).
    """
    n = len(gold_ids)
    hits = sum(bool(set(gold_ids[i]).intersection(topk_indices[i])) for i in range(n))
    return hits / n if n else 0.0

# %% [markdown]
# ### 🧩 Step 2 – Set Dataset Split.
#
# Before running the cell below, make sure to **set the dataset split** correctly.
#
# 1. **Validation Phase**
#    - Fill in the required code sections.
#    - Run **all cells** in the notebook using the **validation (`val`)** split.
#    - Verify that your implementation and performance metrics are satisfactory.
#
# 2. **Testing Phase**
#    - Once you are satisfied with your results on the validation split, **restart the runtime/session** to ensure a clean environment.
#    - Then, run **all cells again** using the **test** split.
#
# ⚠️ **Note:** The ground truth labels for the test split are **not visible**.
# As a result, the notebook may show **lower scores** on the test split, even if your implementation performs well on validation.
# Your final test predictions will be evaluated separately.

# %%
CURRENT_SPLIT = "val" # set current split

# %%
# setting the dataset variables
retrieval_dataset = datasets[CURRENT_SPLIT]
gold_ids  = [item["correct_document_ids"] for item in datasets[CURRENT_SPLIT]]
queries   = [item["query"] for item in datasets[CURRENT_SPLIT]]
documents = datasets[CURRENT_SPLIT][0]["all_documents"]
answer_choices = []
for item in datasets[CURRENT_SPLIT]:
  item_choices = item['choices']
  item_choices['correct_choice'] = item['correct_choice']
  answer_choices.append(item_choices)

# %% [markdown]
# ### 🧩 Step 3 – Run Retriever, Visualize Examples, and Save Results
#
# In this step, you will:
#
# 1. **Run the Retriever**
#    - Execute the retrieval pipeline using your selected retriever type (e.g., `bm25`, `instructor`, or `qwen3` model).
#    - Compute similarity scores between all **queries** and **documents**.
#    - Evaluate **Hit@K** metrics across different values of K (e.g., 1, 2, 4, 8, 16, 32, 64).
#
# 2. **Visualize Retrieval Examples**
#    - Randomly inspect a few **Top-1 retrieved documents** for sample queries.
#    - Check whether the retrieved results match the **ground-truth document IDs**.
#
# 3. **Save Retrieval Results**
#    - Store the computed top-K indices, retrieved documents, and hit rates in a dictionary (e.g., `TOP_K_RETRIEVAL_RESULTS`).
#    - Later, write these results to disk for submission or further evaluation.
#
# ⚙️ **Tip:**
# Experiment with multiple retrievers, but **use the one that achieves the highest HitRate on your validation split** when running the final cells, since this retriever will be used for the generation stage in the next section.
#
#
# 📊 **Outcome:**
# After completing this step, you should see printed **Hit@K** scores (e.g., HitRate@1, HitRate@4, HitRate@16, etc.) and several sample retrievals that help verify the correctness of your retriever implementation.

# %%
# Try retriever "bm25" and "model" with embedding models such as "hkunlp/instructor-large" or "Qwen/Qwen3-Embedding-0.6B"
# <fill block>
RETRIEVER_TYPE, RETRIEVER_MODEL_NAME = "model", "Qwen/Qwen3-Embedding-0.6B"
# </fill block>

TOP_K_RETRIEVAL_RESULTS = dict() # saving the retrieval results here.
similarity_scores = get_similarity_scores(retrieval_dataset=retrieval_dataset, retriever_type=RETRIEVER_TYPE, model_name=RETRIEVER_MODEL_NAME).cpu()

ks = (1, 2, 4, 8, 16, 32, 64)
for k in ks:
    topk_idx, topk_docs = get_topk(similarity_scores, documents, k=k)
    if k not in TOP_K_RETRIEVAL_RESULTS:
      TOP_K_RETRIEVAL_RESULTS[k] = dict()
    hitrate = hitrate_at_k_from_indices(topk_idx, gold_ids)
    TOP_K_RETRIEVAL_RESULTS[k] = {'indices': topk_idx, 'documents': topk_docs, 'hitrate': hitrate}
    if k == 1 and CURRENT_SPLIT == "val":
      assert hitrate > 0.80, "For validation split the hitrate@1 should be greater than 0.8"
    print(f"HitRate@{k}: {hitrate:.3f}")
# Out:
# Using retriever type: model, model name: Qwen/Qwen3-Embedding-0.6B
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.19G [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/313 [00:00<?, ?B/s]
# HitRate@1: 0.870
# HitRate@2: 0.897
# HitRate@4: 0.920
# HitRate@8: 0.940
# HitRate@16: 0.963
# HitRate@32: 0.979
# HitRate@64: 0.991

# %%
random.seed(42)
print("\n=== Sample Top-1 Retrievals (Random Order) ===")
for i in random.sample(range(len(queries)), k=min(20, len(queries))):
    top1_idx = TOP_K_RETRIEVAL_RESULTS[1]['indices'][i][0]
    gold = set(gold_ids[i])
    is_hit = top1_idx in gold
    symbol = "✅" if is_hit else "❌"

    print(f"\n{symbol} Query {i}: {queries[i]}")
    print(f"  ➤ Top-1 Retrieved Doc[{top1_idx}]: {topk_docs[i][0][:150]}{'...' if len(topk_docs[i][0])>150 else ''}")
    print(f"  🎯 Ground Truth IDs: {sorted(gold)}")
# Out:
# === Sample Top-1 Retrievals (Random Order) ===
#
# ✅ Query 1309: 1986 German Badminton Championships – women's doubles is followed by
#   ➤ Top-1 Retrieved Doc[328]: Drishyam 2 follows 1986 German Badminton Championships – women's doubles.
#   🎯 Ground Truth IDs: [328]
#
# ✅ Query 228: The name of the continent which the country of citizenship of Sunil Lahri is part of is
#   ➤ Top-1 Retrieved Doc[56]: The name of the country of citizenship of Sunil Lahri is Viceroyalty of New Granada.
#   🎯 Ground Truth IDs: [56]
#
# ✅ Query 51: The name of the spouse of the mother of Richard Nixon is
#   ➤ Top-1 Retrieved Doc[11]: The name of the mother of Richard Nixon is Caretene.
#   🎯 Ground Truth IDs: [11]
#
# ✅ Query 563: The name of the child of Dorothy Bridges is
#   ➤ Top-1 Retrieved Doc[132]: The names of the siblings of Jeff Bridges are Carol Nugent.
#   🎯 Ground Truth IDs: [132]
#
# ❌ Query 501: The name of the spouse of the founder of Most Eminent Order of the Indian Empire is
#   ➤ Top-1 Retrieved Doc[367]: The name of the spouse of Osman I is Elna Kiljander.
#   🎯 Ground Truth IDs: [123]
#
# ✅ Query 457: The occupation of the spouse of John Challis is
#   ➤ Top-1 Retrieved Doc[109]: The name of the spouse of John Challis is Anna Leibbrand.
#   🎯 Ground Truth IDs: [109]
#
# ✅ Query 285: The name of the award the screenwriter of Deadly Illusions won is
#   ➤ Top-1 Retrieved Doc[68]: The name of the screenwriter of Deadly Illusions is Péter Bacsó.
#   🎯 Ground Truth IDs: [68]
#
# ✅ Query 209: The name of the continent which BBC World Service is part of is
#   ➤ Top-1 Retrieved Doc[53]: The name of the country which BBC World Service is associated with is Mandatory Iraq.
#   🎯 Ground Truth IDs: [53]
#
# ✅ Query 1385: The occupation of the director of Veeram is
#   ➤ Top-1 Retrieved Doc[347]: The name of the director of Veeram is Campino.
#   🎯 Ground Truth IDs: [347]
#
# ✅ Query 1116: The name of the continent which the country of citizenship of Bernard Madoff is part of is
#   ➤ Top-1 Retrieved Doc[278]: The name of the country of citizenship of Bernard Madoff is Duchy of Saxe-Coburg and Gotha.
#   🎯 Ground Truth IDs: [278]
#
# ✅ Query 178: The official language of the country of citizenship of Katey Sagal is
#   ➤ Top-1 Retrieved Doc[46]: The name of the country of citizenship of Katey Sagal is South African Republic.
#   🎯 Ground Truth IDs: [46]
#
# ✅ Query 1209: The occupation of the screenwriter of Birds of Prey is
#   ➤ Top-1 Retrieved Doc[303]: The name of the screenwriter of Birds of Prey is Wilhelm Mach.
#   🎯 Ground Truth IDs: [303]
#
# ✅ Query 864: SCAPIN-1561: Repatriation Of Italian Nationals is followed by
#   ➤ Top-1 Retrieved Doc[219]: Great Expectations is followed by SCAPIN-1561: Repatriation Of Italian Nationals.
#   🎯 Ground Truth IDs: [219]
#
# ❌ Query 65: The names of the siblings of the founder of The Family are
#   ➤ Top-1 Retrieved Doc[326]: The names of the siblings of Michael Jackson are Isaac Newton Van Nuys.
#   🎯 Ground Truth IDs: [14]
#
# ❌ Query 61: The name of the siblings in law of Mayte Garcia are
#   ➤ Top-1 Retrieved Doc[141]: The names of the siblings of Nicolas Cage are Sally Hemings.
#   🎯 Ground Truth IDs: [14]
#
# ❌ Query 191: The name of the country of citizenship of the author of Ethical considerations in HIV cure research: points to consider is
#   ➤ Top-1 Retrieved Doc[360]: The name of the country of citizenship of Howard Hesseman is Guyana.
#   🎯 Ground Truth IDs: [48]
#
# ❌ Query 447: The name of the siblings in law of Soyarabai are
#   ➤ Top-1 Retrieved Doc[10]: The names of the siblings of Prince Harry, Duke of Sussex are Shiban.
#   🎯 Ground Truth IDs: [105]
#
# ✅ Query 476: The occupation of the director of Trolls World Tour is
#   ➤ Top-1 Retrieved Doc[114]: The name of the director of Trolls World Tour is Solvejg Eriksen.
#   🎯 Ground Truth IDs: [114]
#
# ✅ Query 1034: The official language of list of prime ministers of the United Kingdom is
#   ➤ Top-1 Retrieved Doc[256]: The name of the country which list of prime ministers of the United Kingdom is associated with is Early history of Kedah.
#   🎯 Ground Truth IDs: [256]
#
# ✅ Query 1232: The name of the spouse of the mother of Demi Moore is
#   ➤ Top-1 Retrieved Doc[309]: The name of the mother of Demi Moore is Queen Myeongdeok.
#   🎯 Ground Truth IDs: [309]

# %%
# Save the retrieval results.

output_file = f"anlp_hw2_outputs/retrieval_results_{RETRIEVER_TYPE}_{RETRIEVER_MODEL_NAME.replace('/', '.')}_{CURRENT_SPLIT}.json"
os.makedirs(os.path.dirname(output_file), exist_ok=True)

with open(output_file, "w") as f:
    json.dump(TOP_K_RETRIEVAL_RESULTS, f, indent=2)

print(f"✅ Retrieval results saved successfully to: {output_file}")
# Out:
# ✅ Retrieval results saved successfully to: anlp_hw2_outputs/retrieval_results_model_Qwen.Qwen3-Embedding-0.6B_val.json

# %% [markdown]
# ### 🧠 Section 4 — Generate Answers with an LLM
#
# In this section, you’ll use a **generator LLM** to answer queries **conditioned on the retrieved documents**. Your objective is to improve the model’s reasoning and accuracy by systematically experimenting with different configurations.
#
# **Your tasks:**
# 1. **Try different generator models**
#    - Experiment with different small models.
#    - Compare their performance on the validation split to identify which model generalizes best.
#
# 2. **Tune the input prompts**
#    - Refine the system and user prompts to improve reasoning structure and output consistency.
#    - Emphasize step-by-step reasoning and enforce strict JSON-only answers.
#
# 3. **Vary the number of top-K retrieved documents**
#    - Experiment with different context sizes (e.g., K = 0, 1, 2, 4, 8, 16, 64).
#    - Observe how increasing or decreasing K affects both accuracy and generation cost.
#
# 4. **Save your results to disk**
#    - Store outputs for atleast two configuration (model, K, prompt variant) (one with K>=1 and one with K=0) on both **validation** and **test** splits.
#
# > **Note:** Test split labels are hidden, so accuracy will appear low or undefined. This is expected — focus on achieving strong validation performance first, then run inference on the test split for evaluation.

# %% [markdown]
# ### 🧩 Step 1 – Load the retrieval results from the best found retriever
#
# In this step, you will **reload the retrieval outputs** obtained from the best-performing retriever model (identified in the previous section).
# These results contain the **top-K retrieved documents** for each query and will serve as input for the **generator LLM** in the next stages.
#
# You’ll load the saved `.json` file from the `outputs/` directory, which stores the retrieval scores and document IDs for both validation and test splits.

# %%
RETRIEVER_TYPE, RETRIEVER_MODEL_NAME = "model", "Qwen/Qwen3-Embedding-0.6B"
retrieval_results_file = f"anlp_hw2_outputs/retrieval_results_{RETRIEVER_TYPE}_{RETRIEVER_MODEL_NAME.replace('/', '.')}_{CURRENT_SPLIT}.json"
TOP_K_RETRIEVAL_RESULTS = json.load(open(retrieval_results_file))

# %% [markdown]
# ### 🧩 Step 2 – Setup the generator LLM using vLLM
#
# In this step, you will **initialize the generator model** that will produce answers based on the retrieved documents.
# The generator LLM takes as input the query, context (retrieved top-K documents), and the prompt instructions — and outputs the most likely correct answer.
#
# You will:
# 1. **Select the generator model**
#    Choose from models like `Qwen2.5-3B-Instruct`, `Llama-3.2-1B-Instruct`, or `SmolLM3-3B`.
#    Larger models generally exhibit stronger reasoning abilities but require more GPU memory and may take longer to load.
#
# 2. **Initialize the tokenizer**
#    The tokenizer formats the input messages using the appropriate chat template (system + user roles) before sending them to the model.
#
# 3. **Load the model with vLLM**
#    Use the `LLM()` class from [**vLLM**](https://vllm.ai) — a high-performance inference engine optimized for **fast, memory-efficient, and scalable generation**.
#    vLLM uses techniques such as **PagedAttention**, dynamic batching, and GPU memory sharing, allowing you to run large models efficiently with minimal latency.
#
#    Key parameters to tune:
#    - `dtype`: `"float16"` or `"bfloat16"` (depending on GPU support)
#    - `tensor_parallel_size`: Increase if running on multiple GPUs
#    - `gpu_memory_utilization`: Adjust between `0.85–0.95` depending on available memory
#    - `max_model_len`: Set according to the model’s context window
#
# > 💡 **Tip:** If any model fails to load, it’s likely due to **insufficient free GPU memory**.
# > Before retrying, free up GPU memory by restarting the kernel.

# %%
# Try different small generator models such as "Qwen/Qwen2.5-3B-Instruct" or "meta-llama/Llama-3.2-1B-Instruct" or "HuggingFaceTB/SmolLM3-3B"
# <fill block>
GENERATOR_NAME = "HuggingFaceTB/SmolLM3-3B"
# </fill block>

# ---- Initialize tokenizer (for chat templating) ----
generator_tokenizer = AutoTokenizer.from_pretrained(GENERATOR_NAME)

# ---- Initialize vLLM engine ----
generator_model = LLM(
    model=GENERATOR_NAME,
    dtype="float16",                # or "bfloat16" if supported
    tensor_parallel_size=1,         # increase if multi-GPU
    gpu_memory_utilization=0.85,     # try 0.85–0.95 depending on GPU headroom
    max_model_len=2048,
    enable_prefix_caching=True      # saves the compute if prompts share a common prefix (e.g. a system prompt)
)
print(f"✅ Model {GENERATOR_NAME} loaded successfully.")
# Out:
# INFO 10-31 22:29:07 [utils.py:233] non-default args: {'dtype': 'float16', 'max_model_len': 2048, 'enable_prefix_caching': True, 'gpu_memory_utilization': 0.85, 'disable_log_stats': True, 'model': 'HuggingFaceTB/SmolLM3-3B'}
# INFO 10-31 22:29:09 [model.py:547] Resolved architecture: SmolLM3ForCausalLM
# WARNING 10-31 22:29:09 [model.py:1733] Casting torch.bfloat16 to torch.float16.
# INFO 10-31 22:29:09 [model.py:1510] Using max model len 2048
# INFO 10-31 22:29:09 [scheduler.py:205] Chunked prefill is enabled with max_num_batched_tokens=8192.
# INFO 10-31 22:29:57 [llm.py:306] Supported_tasks: ['generate']
# ✅ Model HuggingFaceTB/SmolLM3-3B loaded successfully.

# %% [markdown]
# ### 🧩 Step 3 – Tune the Prompts to Generator
#
# In this step, you will design **prompt templates** that will guide your **generator model** (e.g., `Llama-3`, `Qwen2`, `Gemma`, etc.) to produce accurate and well-structured answers based on the retrieved documents.
#
# Your task is to:
#
# 1. **Understand the Context and Task**
#    - You are given a list of modified WIKIDATA facts (`contextual_facts`), a question (`question`), and multiple answer choices (`answer_options`).
#    - The model must reason over the modified facts — treating them as the *true, authoritative version* — and pick the correct choice.
#
# 2. **Write the System and User Prompts**
#    - The **system prompt** should explain the reasoning process and enforce the correct output format (a single JSON line like `{"correct_choice": "A"}`).
#    - The **user prompt** should include the given context, the question, and all answer choices.
#
# 3. **Goal**
#    - Guide the model to reason step-by-step using the provided facts.
#    - Ensure the final output is machine-parseable (strict JSON schema) so it can be automatically evaluated.
#
# 4. **Instructions**
#    - Fill the `# <fill block> ... </fill block>` section by writing both:
#      - A clear system instruction on how to reason and format the answer.
#      - A user instruction that includes the contextual facts, question, and answer choices.
#    - Verify that the return value is a list of two messages:
#      ```python
#      [
#        {"role": "system", "content": sys},
#        {"role": "user", "content": user}
#      ]
#      ```
#
# 🧠 *Tip:* Try different phrasing styles for the system and user prompts — for instance, make the system more detailed and the user shorter (or vice versa) — to see which yields the best validation accuracy.

# %%
def prepare_generator_input(contextual_facts, question, answer_options):
    ctx = " ".join(contextual_facts)
    answer_choices_string = "\n".join([f"{choice}: {answer_options['choice_' + choice]}" for choice in ['A', 'B', 'C', 'D', 'E', 'F']])
    # NOTE: Write the system and user prompt.
    # System prompt should guide the LLM about how to use context, how to reason and how to geneate output in the parseable format {"correct_choice": "label"}, where "label" can only be "A", "B", "C", "D", "E", "F".
    # User prompt will be dependent on contextual facts, question and answer_option.
    # More tips on tuning prompts:
    # =========================
    # SYSTEM PROMPT CHECKLIST
    # =========================
    # Purpose: Teach the model HOW to think and respond.

    # 1) Define model role clearly:
    #       - State the model is an expert in Wikidata facts and logical reasoning.

    # 2) Explain function of the provided context:
    #       - Context temporarily modifies/overrides relationships in the Wikidata graph.

    # 3) Set precedence of new facts:
    #       - Modified facts in context take precedence over any prior/latent knowledge.

    # 4) Specify reasoning style:
    #       - Require 3–6 concise, non-redundant bullet points.
    #       - Bullets must reference the modified relationships and their ripple effects.

    # 5) Enforce output structure:
    #       - Exactly two sections, in order:
    #         1) "Reasoning:" (bullets)
    #         2) "Final:" (single JSON line)

    # 6) Enforce strict JSON format in Final:
    #       - Exactly: {"correct_choice": "label"}
    #       - "label" ∈ {"A", "B", "C", "D", "E", "F"}

    # 7) Restrict JSON location:
    #       - JSON must appear ONLY in the Final section (never inside Reasoning).

    # 8) Encourage step-by-step logic:
    #       - Instruct to explain how modified links cause one choice to be correct.


    # =======================
    # USER PROMPT CHECKLIST
    # =======================
    # Purpose: Provide the specific instance (facts, question, choices).

    # 1) Include contextual facts:
    #       - Start with "Context:" containing the edited/modified Wikidata relationships.

    # 2) Present the question clearly:
    #       - Follow with "Question:" that refers to entities impacted by the context.

    # 3) List answer choices:
    #       - End with "Answer Choices:" listing options A–F, clearly labeled.

    # 4) Keep structure consistent:
    #       - Order must be: Context → Question → Answer Choices.
    #       - Use clean line breaks; avoid extra filler text.

    # 5) Avoid meta-instructions:
    #       - Do NOT include reasoning guidance or examples—only task content.

    # 6) Keep inputs parseable:
    #       - Consistent labels and formatting to allow automated extraction.


    # <fill block>
    sys = (
    "You will answer multiple-choice questions using only the facts in the Context. "
    "If anything conflicts with your own knowledge, follow the Context instead.\n\n"
    "Write a short reasoning section as bullet points under the heading 'Reasoning:'. "
    "Keep it brief and refer to relationships mentioned in the Context.\n\n"
    "After that, add a 'Final:' section with exactly one JSON line:\n"
    '  {\"correct_choice\": \"X\"}\n'
    "Use only one of A, B, C, D, E, F. "
    "Do not include JSON anywhere else."
    )

    user = (
    "Context:\n"
    f"{ctx}\n\n"
    "Question:\n"
    f"{question}\n\n"
    "Answer Choices:\n"
    f"{answer_choices_string}"
    )
    # </fill block>

    return [
        {"role": "system", "content": sys},
        {"role": "user", "content": user}
    ]

# %%
def chat_response(list_messages, generator_model, generator_tokenizer, max_new_tokens, temperature=0.0):
    # Prepare the chat input text
    prompts = []
    for messages in list_messages:
      prompt = generator_tokenizer.apply_chat_template(
          messages,
          tokenize=False,
          add_generation_prompt=True
      )
      prompts.append(prompt)

    # --- Define sampling parameters ---
    sp = SamplingParams(
        temperature=temperature,
        max_tokens=max_new_tokens,
    )

    # --- Run inference with vLLM ---
    responses = generator_model.generate(prompts, sp)
    responses = [response.outputs[0].text for response in responses]

    return responses

# %% [markdown]
# ### 🧩 Step 4 – Prepare Generator Inputs with Top-K Retrieved Documents
#
# In this step, you’ll **combine the retriever results** (Top-K documents) with the query and answer options to form the **input messages** for your generator LLM.
#
# Your tasks:
#
# 1. **Select K (number of retrieved documents)**
#    - Set the variable `K` to control how many top-retrieved documents are passed to the generator.
#    - Try values like `K = 1`, `K = 2`, `K = 4`, or `K = 8` to observe how retrieval depth affects generation accuracy.
#    - When `K = 0`, the model receives **no context** (baseline, zero-context reasoning).
#
# 2. **Sample Evaluation Queries**
#    - A random subset of queries will be selected to visualize input examples and sanity-check that the right documents are being used.
#
# 3. **Generate Formatted Messages**
#    - For each query, you will create a message pair:
#      - **System + User prompts** (from `prepare_generator_input`)
#      - **Ground-truth answer label**
#    - These structured inputs will later be passed to your generator in the next step for inference.
#
# 4. **Inspect a Few Samples**
#    - After preparing the list `messages_and_labels`, print a few samples to confirm:
#      - Retrieved context snippets
#      - Corresponding question and answer choices
#      - JSON-formatted LLM messages and correct answer labels
#
# 💡 *Tip:* Start with `K = 0` and `K = 1` for quick debugging, then progressively increase K. Larger K may improve recall but can hurt precision if irrelevant documents are added.

# %%
# NOTE: Choose how many top-k documents (experiment with atleast K=0 and K=1) you want to put the in the context of generator LLM.
# <fill block>
K = 1
# </fill block>

if K == 0:
  topk_idx, topk_docs = [[] for _ in range(len(TOP_K_RETRIEVAL_RESULTS[str(1)]['indices']))], [[] for _ in range(len(TOP_K_RETRIEVAL_RESULTS[str(1)]['documents']))]
else:
  topk_idx, topk_docs = TOP_K_RETRIEVAL_RESULTS[str(K)]['indices'], TOP_K_RETRIEVAL_RESULTS[str(K)]['documents']

messages_and_labels = [
    {
        'messages': prepare_generator_input(topk_docs[i], queries[i], answer_choices[i]),
        'correct_choice': answer_choices[i]['correct_choice'].split('_')[-1],
    }
    for i in range(len(queries))
]

# %%
# visualise some geneator inptus
random.seed(42)
indices = random.sample(range(len(queries)), k=5)

for i in indices:
    print(f"\n=== Query {i} ===")
    print(f"❓ {queries[i]}")
    print(f"📚 Context ({len(topk_docs[i])} docs):")
    for j, doc in enumerate(topk_docs[i]):
        print(f"  [{j+1}] {doc[:150]}{'...' if len(doc)>150 else ''}")
    print(f"\n🧠 LLM Messages:\n{json.dumps(messages_and_labels[indices.index(i)]['messages'], indent=4)}\n")
    print(f"Correct Choice:\n{messages_and_labels[indices.index(i)]['correct_choice']}")
# Out:
# === Query 1309 ===
# ❓ 1986 German Badminton Championships – women's doubles is followed by
# 📚 Context (1 docs):
#   [1] Drishyam 2 follows 1986 German Badminton Championships – women's doubles.
#
# 🧠 LLM Messages:
# [
#     {
#         "role": "system",
#         "content": "You will answer multiple-choice questions using only the facts in the Context. If anything conflicts with your own knowledge, follow the Context instead.\n\nWrite a short reasoning section as bullet points under the heading 'Reasoning:'. Keep it brief and refer to relationships mentioned in the Context.\n\nAfter that, add a 'Final:' section with exactly one JSON line:\n  {\"correct_choice\": \"X\"}\nUse only one of A, B, C, D, E, F. Do not include JSON anywhere else."
#     },
#     {
#         "role": "user",
#         "content": "Context:\nThe name of the country of citizenship of Leonardo DiCaprio is Syria.\n\nQuestion:\nThe name of the currency in the country of citizenship of Leonardo DiCaprio is\n\nAnswer Choices:\nA: Japanese yen\nB: Euro\nC: Canadian dollar\nD: Syrian pound\nE: United States dollar\nF: Pound sterling"
#     }
# ]
#
# Correct Choice:
# D
#
# === Query 228 ===
# ❓ The name of the continent which the country of citizenship of Sunil Lahri is part of is
# 📚 Context (1 docs):
#   [1] The name of the country of citizenship of Sunil Lahri is Viceroyalty of New Granada.
#
# 🧠 LLM Messages:
# [
#     {
#         "role": "system",
#         "content": "You will answer multiple-choice questions using only the facts in the Context. If anything conflicts with your own knowledge, follow the Context instead.\n\nWrite a short reasoning section as bullet points under the heading 'Reasoning:'. Keep it brief and refer to relationships mentioned in the Context.\n\nAfter that, add a 'Final:' section with exactly one JSON line:\n  {\"correct_choice\": \"X\"}\nUse only one of A, B, C, D, E, F. Do not include JSON anywhere else."
#     },
#     {
#         "role": "user",
#         "content": "Context:\nThe name of the country of citizenship of Leonardo DiCaprio is Syria.\n\nQuestion:\nThe official language of the country of citizenship of Leonardo DiCaprio is\n\nAnswer Choices:\nA: English\nB: Spanish\nC: German\nD: French\nE: Arabic\nF: Italian"
#     }
# ]
#
# Correct Choice:
# E
#
# === Query 51 ===
# ❓ The name of the spouse of the mother of Richard Nixon is
# 📚 Context (1 docs):
#   [1] The name of the mother of Richard Nixon is Caretene.
#
# 🧠 LLM Messages:
# [
#     {
#         "role": "system",
#         "content": "You will answer multiple-choice questions using only the facts in the Context. If anything conflicts with your own knowledge, follow the Context instead.\n\nWrite a short reasoning section as bullet points under the heading 'Reasoning:'. Keep it brief and refer to relationships mentioned in the Context.\n\nAfter that, add a 'Final:' section with exactly one JSON line:\n  {\"correct_choice\": \"X\"}\nUse only one of A, B, C, D, E, F. Do not include JSON anywhere else."
#     },
#     {
#         "role": "user",
#         "content": "Context:\nThe name of the country of citizenship of Leonardo DiCaprio is Syria.\n\nQuestion:\nThe name of the continent which the country of citizenship of Leonardo DiCaprio is part of is\n\nAnswer Choices:\nA: Africa\nB: South America\nC: North America\nD: Asia\nE: Europe\nF: Australia"
#     }
# ]
#
# Correct Choice:
# D
#
# === Query 563 ===
# ❓ The name of the child of Dorothy Bridges is
# 📚 Context (1 docs):
#   [1] The names of the siblings of Jeff Bridges are Carol Nugent.
#
# 🧠 LLM Messages:
# [
#     {
#         "role": "system",
#         "content": "You will answer multiple-choice questions using only the facts in the Context. If anything conflicts with your own knowledge, follow the Context instead.\n\nWrite a short reasoning section as bullet points under the heading 'Reasoning:'. Keep it brief and refer to relationships mentioned in the Context.\n\nAfter that, add a 'Final:' section with exactly one JSON line:\n  {\"correct_choice\": \"X\"}\nUse only one of A, B, C, D, E, F. Do not include JSON anywhere else."
#     },
#     {
#         "role": "user",
#         "content": "Context:\nThe name of the country of citizenship of Leonardo DiCaprio is Syria.\n\nQuestion:\nThe name of the capital city of the country of citizenship of Leonardo DiCaprio is\n\nAnswer Choices:\nA: Rome\nB: Paris\nC: London\nD: Washington, D.C.\nE: Damascus\nF: Ottawa"
#     }
# ]
#
# Correct Choice:
# E
#
# === Query 501 ===
# ❓ The name of the spouse of the founder of Most Eminent Order of the Indian Empire is
# 📚 Context (1 docs):
#   [1] The name of the spouse of Osman I is Elna Kiljander.
#
# 🧠 LLM Messages:
# [
#     {
#         "role": "system",
#         "content": "You will answer multiple-choice questions using only the facts in the Context. If anything conflicts with your own knowledge, follow the Context instead.\n\nWrite a short reasoning section as bullet points under the heading 'Reasoning:'. Keep it brief and refer to relationships mentioned in the Context.\n\nAfter that, add a 'Final:' section with exactly one JSON line:\n  {\"correct_choice\": \"X\"}\nUse only one of A, B, C, D, E, F. Do not include JSON anywhere else."
#     },
#     {
#         "role": "user",
#         "content": "Context:\nThe name of the country of citizenship of Leonardo DiCaprio is Syria.\n\nQuestion:\nThe name of the head of government of the country of citizenship of Leonardo DiCaprio is\n\nAnswer Choices:\nA: Rishi Sunak\nB: Hussein Arnous\nC: Olaf Scholz\nD: Narendra Modi\nE: Joe Biden\nF: Justin Trudeau"
#     }
# ]
#
# Correct Choice:
# B

# %% [markdown]
# ### 🧩 Step 5 – Compute Accuracy and Save the Generated Responses
#
# In this final step, you’ll **evaluate your generator model** by comparing its predicted answers against the ground truth labels and compute overall accuracy.
#
# Your tasks:
#
# 1. **Parse and Validate Model Outputs**
#    - The generator produces answers in JSON format (e.g., `{"correct_choice": "A"}`).
#    - The function `repair_json()` ensures that slightly malformed outputs (like missing braces or quotes) are corrected before evaluation.
#
# 2. **Compute Accuracy and Parsing Error**
#    - For each response, extract the predicted label and compare it with the true label.
#    - If the model output fails to parse correctly, it’s counted toward the **parsing error fraction**.
#    - The `accuracy()` function returns both:
#      - `accuracy`: fraction of correctly predicted answers
#      - `parse_error_fraction`: percentage of invalid or unparsable outputs
#
# 3. **Run Generator and Evaluate**
#    - Use the `chat_response()` function to generate predictions for all prepared prompts.
#    - Pass these responses into `accuracy()` to compute the final metrics.
#
# 4. **Inspect Results**
#    - Print the final accuracy and parsing error (both shown as percentages).
#    - A progress bar displays how many queries were processed successfully.
#    - Example output:
#      ```
#      Final Accuracy: 50.60% || Parsing Error: 1.07%
#      ```
#
# 5. **(Optional Extension)**
#    - Save responses and scores for further analysis:
#      - Try saving them as a JSONL file for leaderboard or post-hoc evaluation.
#      - Example: `json.dump({"responses": responses, "labels": labels}, open('results/generator_outputs.json', 'w'))`
#
# 💡 *Tip:* A low parsing error (<2%) indicates your prompt formatting is robust.
# If parsing errors spike, revisit your system prompt or tighten JSON output instructions.
#
# ---
#
# 📘 **Runtime Note:**
# On a **T4 GPU**, the validation set should take **about one hour** to run.
# If you have access to the **free *Colab Pro ([Student Edition](https://colab.research.google.com/signup))***, you can switch your runtime to an **A100 GPU**, which will complete the validation run in **about one minute**.

# %%
def accuracy(responses, labels):
    pred_labels = []
    parsing_error = 0.0
    for response, label in zip(responses, labels):
        pred_obj = repair_json(response, return_objects=True)
        if isinstance(pred_obj, list):
            pred_obj = pred_obj[-1]
        if isinstance(pred_obj, dict) and "correct_choice" in pred_obj:
            pred_label = pred_obj["correct_choice"]
        else:
            pred_label = "A"  # default fallback
            parsing_error += 1
        pred_labels.append(pred_label)

    correct = sum(p == l for p, l in zip(pred_labels, labels))
    return {"accuracy": correct / len(labels) if labels else 0.0, "parse_error_fraction": parsing_error / len(labels) if labels else 0.0}

# %%
generator_messages = [item['messages'] for item in messages_and_labels]
labels = [item['correct_choice'] for item in messages_and_labels]

responses = chat_response(
    generator_messages, generator_model, generator_tokenizer, max_new_tokens=1502
)

# compute final accuracy
results = accuracy(responses, labels)
print(f"Final Accuracy: {results['accuracy']:.3%} || Parsing Error: {results['parse_error_fraction']:.4%}")
assert results['accuracy'] > 0.5, "Final accuracy should be greater than 0.5 after tuning value of K and prompt."
assert results['parse_error_fraction'] < 0.05, "Parsing error fraction should be less than 5%."
# Out:
# Adding requests:   0%|          | 0/1492 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1492 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s…
# Final Accuracy: 50.469% || Parsing Error: 1.4745%

# %%
# Save the generator results.
output_file = f"anlp_hw2_outputs/generator_results_{GENERATOR_NAME.replace('/', '.')}_K-{K}_{CURRENT_SPLIT}.json"
os.makedirs(os.path.dirname(output_file), exist_ok=True)

with open(output_file, "w") as f:
    json.dump({"responses": responses, "generator_messages": generator_messages}, f, indent=2)

print(f"✅ Generator results saved successfully to: {output_file}")
# Out:
# ✅ Generator results saved successfully to: anlp_hw2_outputs/generator_results_HuggingFaceTB.SmolLM3-3B_K-1_val.json

# %% [markdown]
# ## 🔎 Section 5 — Upload Your Outputs to Hugging Face Hub
#
# In this step, you will upload your generated **JSON output files** to your **own Hugging Face repository**.
# This ensures your results are versioned, shareable, and verifiable by the instructors.
#
# #### Instructions
#
# 1. **Login to Hugging Face**  (you already did this in the beginning)
#    Run the following in a code cell:
#    ```bash
#    huggingface-cli login
#    ```
#    Get your access token from:
#    <https://huggingface.co/settings/tokens>
#
# 2. **Run the upload cell below**
#    It will:
#    - Create a repository named `anlp-hw2-outputs` under your username (if it doesn’t already exist).
#    - Upload all `.json` files inside `/content/anlp_hw2_outputs/`.
#    - Print a **commit URL** and a **repository URL** upon success.
#
# 3. **Verify your upload**
#    - Open the printed commit URL in your browser.
#    - Confirm that all expected `.json` files are present in the repository.
#    - Ensure each file has valid JSON content and is non-empty.
#
# #### ✅ Verification Checklist
#
# - `/content/anlp_hw2_outputs/` contains multiple `.json` files.
# - All files are visible on Hugging Face and have non-zero size.
# - The commit URL opens correctly and shows your uploaded files.

# %%
from huggingface_hub import HfApi, create_repo, upload_folder

# NOTE: specify your username to upload the upload the test and val results.
# <fill block>
user_name = "jameshan5040"
# </fill block>
repo_id = f"{user_name}/anlp-hw2-outputs"      # 🔹 change this
folder_path = "/content/anlp_hw2_outputs"       # 🔹 local folder path


api = HfApi()
create_repo(repo_id, exist_ok=True)

upload_folder(
    folder_path=folder_path,
    repo_id=repo_id,
    commit_message="Upload JSON outputs",
    ignore_patterns=["*.ipynb", "*.py", "*.DS_Store"],  # optional cleanup
)
# Out:
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...3-Embedding-0.6B_val.json:  88%|########8 | 16.4MB / 18.6MB
# CommitInfo(commit_url='https://huggingface.co/jameshan5040/anlp-hw2-outputs/commit/07824a4fdbd7615348c1def349708a0a50837f16', commit_message='Upload JSON outputs', commit_description='', oid='07824a4fdbd7615348c1def349708a0a50837f16', pr_url=None, repo_url=RepoUrl('https://huggingface.co/jameshan5040/anlp-hw2-outputs', endpoint='https://huggingface.co', repo_type='model', repo_id='jameshan5040/anlp-hw2-outputs'), pr_revision=None, pr_num=None)
